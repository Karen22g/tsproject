# %%
import sys
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import math
from tensorflow import keras
from keras.layers import Dense, Input, Dropout
from keras.optimizers import SGD
from keras.models import Model
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
import os
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import warnings
warnings.filterwarnings("ignore")
from joblib import dump, load
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import re
from keras.layers import LSTM
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.stats.stattools import jarque_bera
import statsmodels.api as sm
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dropout

# %% [markdown]
# # Modelos de redes neuronales

# %% [markdown]
# Apliquemos a continuación Modelos de Redes Neuronales a nuestra serie de tiempo, para conocer el comportamiento del pronóstico que se puede alcanzar a partir de estos. En este apartado estaremos aplicando:
#
# 1. Recurrent neural networks
# 2. Multilayer-perceptron
# 3. Long-short term memory
#
# Durante el análisis se estarán construyendo modelos para distintas combinaciones de épocas, input layers, neuronas y tasas de drop-out.
#
# Cada una de los apartados a continuación incluyen funciones de creación de la red neuronal, además se diseñó una función que retorna el mejor modelo en cada caso, para automatizar la creación y selección para cada combinación. Carguemos los datos:

# %%
df=pd.read_excel("loadsts.xlsx")
df.index = df['Posted_date']
df.index.freq = 'D'
ts = df['Loads']

# %% [markdown]
# En el caso de red neuronales, escalaremos los datos con el fin de disminuir el tiempo de alcance de la convergencia.

# %%
df['loads_escaler'] = df['Loads']
scaler = MinMaxScaler(feature_range=(0, 1))
ts_esc = scaler.fit_transform(np.array(df['loads_escaler']).reshape(-1, 1))

# %% [markdown]
# ## 1. Funciones complementarias

# %% [markdown]
# Al igual que en los otros capítulos estaremos usando las funciones de apoyo para separación de la serie, evaluación de supuestos y evaluación de los 'score' de pronóstico.

# %%
def split(serie, trainportion):
    perct = math.ceil(len(ts) * trainportion)
    perc2 = math.ceil(len(ts)*((1 - trainportion)/2))
    train = serie[0:perct]
    validation = serie[perct:perct+perc2]
    test = serie[perct+perc2:]
    return train, validation, test

# %%
#calculo de los errores
def errors(y_pred, y_real):
    
    mae = mean_absolute_error(y_real, y_pred)
    mape = 100*(sum(abs(((y_real - y_pred)/y_real)))/len(y_real))
    mse = mean_squared_error(y_real , y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_real, y_pred)
    
    return mae, mape, mse, rmse, r2

# %%
#evaluacion de supuestos
def assumptions(residuals):

    warning = ""
    a = 0
    
    #Independency
    #H0: The residuals are independent.
    #H1: The residuals aren't independent.    
    ljung_box_test = acorr_ljungbox(residuals, lags=10, return_df=True)
    ljung_box_pvalue = ljung_box_test['lb_pvalue'].values[0]
    if ljung_box_pvalue < 0.05:
        warning= warning + " The residuals aren't independent"
        a=a+1

    #Normality test
    #H0: The residuals have a normal distribution.
    #H1: The residuals don't have a normal distribution.
    jb_stat, jb_pvalue, skewness, kurtosis = jarque_bera(residuals)
    if jb_pvalue < 0.05:
        a = a+1
        warning = warning + " The residuals do not follow a normal distribution"

    #homocedasticity
    #H0: The residuals are homocedastic.
    #H1: The residuals aren't homocedastic.
    arch_stat, arch_pvalue, _, _ = het_arch(residuals)
    if arch_pvalue < 0.05:
        warning= warning + " The residuals aren't homocedastic"
        a=a+1

    return arch_pvalue, jb_pvalue, ljung_box_pvalue, warning

# %% [markdown]
# A continuación la función con que pronosticaremos los valores de validación y testing para el cálculo de los errores y desempeño del modelo.

# %%
#forecast
def forecast_nw(best_model, X_val):
    preds = best_model.predict(X_val)
    preds = scaler.inverse_transform(preds)
    preds = np.squeeze(preds)
    return preds

# %% [markdown]
# Además, agregaremos la función _makeXy_ que se encarga de organizar la serie de tiempo en un arreglo matricial que genera el input layer de $nbtimesteps$ y la predicción $y$ de un valor a la vez. Durante la selección del mejor modelo de cada tipo de red neuronal estaremos probando esta división para los valores de 3, 4, 5 días para entrenar la red.

# %%
def makeXy(ts, nbtimesteps):
    X = []
    y = []
    for i in range(nbtimesteps, ts.shape[0]):
        X.append(list(ts[i-nbtimesteps:i-1])) #Regressors
        y.append(ts[i]) #Target
    X, y = np.array(X), np.array(y)
    return X, y

# %% [markdown]
# El conjunto de entrenamiento tendrá el 80% datos en este entrenamiento de red neuronal. Guardaremos los conjuntos con los valores reales y los valores escalados a continuación:

# %%
train, val, test = split(ts, 0.8)
train_esc, val_esc, test_esc = split(ts_esc, 0.8)

# %%
plt.figure(figsize=(12, 6))
plt.plot(train.index, train, color='blue', label='Entrenamiento')
plt.plot(val.index, val, color='orange', label='Validación')
plt.plot(test.index, test, color='green', label='Prueba')

plt.title('Conjuntos de Entrenamiento, Validación y Prueba')
plt.xlabel('Fecha')
plt.ylabel('Cargas de Transportadas Diarias')
plt.legend()

plt.show()

# %% [markdown]
# ## 2. Selección de la función de activación

# %% [markdown]
# La función de activación a través de la red neuronal juega un papel crítico en el cálculo de los pesos de cada capa. Existen distintas funciones de activación como 'tanh', 'relu', 'sigmoid', entre otras. A continuación haremos una prueba rápida comparando el desempeño de la red neuronal cuando usamos 'tanh' y cuando usamos 'relu', para conocer cuál mejora el desempeño de las métricas de error.

# %% [markdown]
# Dividamos además el conjunto de training, validación y test para esta prueba.

# %%
X_train, y_train = makeXy(train_esc, 3+1)
X_val, y_val = makeXy(val_esc, 3+1)
X_trainr, y_trainr = makeXy(train, 3+1)
X_valr, y_valr = makeXy(val, 3+1)

# %% [markdown]
# ### 2.1 Test modelo con uso de función 'tanh'

# %% [markdown]
# En este paso estamos generando el modelo de red neuronal Multilayer Perceptron (MLP) para un input de 3 datos, 100 neuronas y una tasa de drop-out de 0.2, estos mismos parámetros los utilizaremos cuando creamos la red neuronal con 'relu'.

# %%
input_layer = Input(shape=(3,), dtype='float32')
dense1 = Dense(100, activation='tanh')(input_layer)
dropout_layer = Dropout(0.2)(dense1)
output_layer = Dense(1, activation='linear')(dropout_layer)

modeltanh = Model(inputs=input_layer, outputs=output_layer)
modeltanh.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# En el siguiente paso guardamos en una carpeta los distintos modelos generados en las épocas revisadas, en este caso solo 10. De estos modelos seleccionaremos el que mejor 'val_loss' tenga, es decir el que mejor pronóstico de la validación alcanzó.

# %%
save_weights_at = os.path.join('keras_models', f'{modeltanh.name}_weights_batch{16}_{{epoch:02d}}-{{val_loss:.4f}}.keras')
save_best = ModelCheckpoint(save_weights_at, monitor='val_loss', verbose=0,
                            save_best_only=True, save_weights_only=False, mode='min', save_freq='epoch');

history_filename = os.path.join('historynn', f'history_{modeltanh.name}_batch{16}.joblib')
history_airp = None

if os.path.exists(history_filename):
    history_filename = history_filename
    print("El archivo '{history_filename}' ya existe. Se ha cargado el historial del entrenamiento.")
        
else:
    history_airp = modeltanh.fit(x=X_train, y=y_train, batch_size=16, epochs=10,
                             verbose=2, callbacks=[save_best], validation_data=(X_val, y_val),
                             shuffle=True);
    dump(history_airp.history, history_filename)
    print("El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'")
# Out:
# Epoch 1/10
# 65/65 - 1s - 16ms/step - loss: 0.0597 - val_loss: 0.0739
# Epoch 2/10
# 65/65 - 0s - 4ms/step - loss: 0.0453 - val_loss: 0.0824
# Epoch 3/10
# 65/65 - 0s - 4ms/step - loss: 0.0431 - val_loss: 0.0805
# Epoch 4/10
# 65/65 - 0s - 5ms/step - loss: 0.0435 - val_loss: 0.0725
# Epoch 5/10
# 65/65 - 0s - 3ms/step - loss: 0.0432 - val_loss: 0.0778
# Epoch 6/10
# 65/65 - 0s - 3ms/step - loss: 0.0422 - val_loss: 0.0729
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0424 - val_loss: 0.0742
# Epoch 8/10
# 65/65 - 0s - 3ms/step - loss: 0.0429 - val_loss: 0.0827
# Epoch 9/10
# 65/65 - 0s - 4ms/step - loss: 0.0416 - val_loss: 0.0767
# Epoch 10/10
# 65/65 - 0s - 2ms/step - loss: 0.0425 - val_loss: 0.0764
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'

# %%
model_dir = 'keras_models'
files = os.listdir(model_dir)
pattern = rf"{re.escape(modeltanh.name)}_weights_batch{16}_(\d+)-([\d\.]+)\.keras"
    
best_val_loss = float('inf')
best_model_file = None
best_model = None
    
for file in files:
    match = re.match(pattern, file)
    if match:
        epoch = int(match.group(1))
        val_loss = float(match.group(2))
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_file = file
    
if best_model_file:
    best_model_path = os.path.join(model_dir, best_model_file)
    print(f"Cargando el mejor modelo: {best_model_file} con val_loss: {best_val_loss}")
    best_model = load_model(best_model_path)
else:
    print("No se encontraron archivos de modelos que coincidan con el patrón.")
# Out:
# Cargando el mejor modelo: functional_33_weights_batch16_04-0.0725.keras con val_loss: 0.0725

# %% [markdown]
# Con el mejor modelo seleccionado por el comando anterior podemos hacer una predicción rápida del conjunto de test.

# %%
y_pred = best_model.predict(X_val)
y_pred = scaler.inverse_transform(y_pred)
y_pred = np.squeeze(y_pred)
errors(y_pred, y_valr) #mae, mape, mse, rmse, r2
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# (20.123026374816895,
#  inf,
#  475.8001378954471,
#  21.812843416103437,
#  -0.1021871566772461)

# %% [markdown]
# Podemos observar que el MAE obtenido con el mejor modelo calculado a partir de la función 'tanh' es 21 unidades. Mucho más que lo que se ha alcanzado con los modelos de suavización exponencial de primer orden incluso.

# %% [markdown]
# ### 2.2 Test modelo con uso de función 'relu'

# %% [markdown]
# Hagamos el mismo procedimiento ahora para modelos calculados con la función de activación 'relu'.

# %%
input_layer = Input(shape=(3,), dtype='float32')
dense1 = Dense(100, activation='relu')(input_layer)
dropout_layer = Dropout(0.2)(dense1)
output_layer = Dense(1, activation='linear')(dropout_layer)

modelrelu = Model(inputs=input_layer, outputs=output_layer)
modelrelu.compile(loss='mean_squared_error', optimizer='adam')

# %%
save_weights_at = os.path.join('keras_models', f'{modelrelu.name}_weights_batch{16}_{{epoch:02d}}-{{val_loss:.4f}}.keras')
save_best = ModelCheckpoint(save_weights_at, monitor='val_loss', verbose=0,
                            save_best_only=True, save_weights_only=False, mode='min', save_freq='epoch');

history_filename = os.path.join('historynn', f'history_{modelrelu.name}_batch{16}.joblib')
history_airp = None

if os.path.exists(history_filename):
    history_filename = history_filename
    print("El archivo '{history_filename}' ya existe. Se ha cargado el historial del entrenamiento.")
        
else:
    history_airp = modelrelu.fit(x=X_train, y=y_train, batch_size=16, epochs=10,
                             verbose=2, callbacks=[save_best], validation_data=(X_val, y_val),
                             shuffle=True);
    dump(history_airp.history, history_filename)
    print("El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'")
# Out:
# Epoch 1/10
# 65/65 - 1s - 16ms/step - loss: 0.0561 - val_loss: 0.0755
# Epoch 2/10
# 65/65 - 0s - 5ms/step - loss: 0.0364 - val_loss: 0.0621
# Epoch 3/10
# 65/65 - 0s - 5ms/step - loss: 0.0322 - val_loss: 0.0587
# Epoch 4/10
# 65/65 - 0s - 5ms/step - loss: 0.0298 - val_loss: 0.0552
# Epoch 5/10
# 65/65 - 0s - 4ms/step - loss: 0.0283 - val_loss: 0.0512
# Epoch 6/10
# 65/65 - 0s - 5ms/step - loss: 0.0269 - val_loss: 0.0478
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0258 - val_loss: 0.0499
# Epoch 8/10
# 65/65 - 0s - 4ms/step - loss: 0.0260 - val_loss: 0.0484
# Epoch 9/10
# 65/65 - 0s - 5ms/step - loss: 0.0263 - val_loss: 0.0467
# Epoch 10/10
# 65/65 - 0s - 4ms/step - loss: 0.0252 - val_loss: 0.0482
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'

# %%
model_dir = 'keras_models'
files = os.listdir(model_dir)
pattern = rf"{re.escape(modelrelu.name)}_weights_batch{16}_(\d+)-([\d\.]+)\.keras"
    
best_val_loss = float('inf')
best_model_file = None
best_model = None
    
for file in files:
    match = re.match(pattern, file)
    if match:
        epoch = int(match.group(1))
        val_loss = float(match.group(2))
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_file = file
    
if best_model_file:
    best_model_path = os.path.join(model_dir, best_model_file)
    print(f"Cargando el mejor modelo: {best_model_file} con val_loss: {best_val_loss}")
    best_model = load_model(best_model_path)
else:
    print("No se encontraron archivos de modelos que coincidan con el patrón.")
# Out:
# Cargando el mejor modelo: functional_35_weights_batch16_09-0.0467.keras con val_loss: 0.0467

# %%
y_pred = best_model.predict(X_val)
y_pred = scaler.inverse_transform(y_pred)
y_pred = np.squeeze(y_pred)
errors(y_pred, y_valr) #mae, mape, mse, rmse, r2
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# (13.549216758728027,
#  inf,
#  306.27162197136806,
#  17.500617759706884,
#  0.29052430391311646)

# %% [markdown]
# Como podemos observar el MAE para los mismos parámetros utilizados tiene 6.5 unidades menos que cuando se usa la función 'tanh'. Por lo que estaremos usando la función 'relu' en la creación de nuestras funciones de redes neuronales.

# %% [markdown]
# ## 3. Recurrent neural networks (RNN)

# %%
def create_RNN(neurons, shape, dropout_rate): #Creación RNN
    model_RNN = Sequential()
    model_RNN.add(SimpleRNN(neurons, input_shape=(shape,1), activation='relu'))
    model_RNN.add(Dropout(dropout_rate))
    model_RNN.add(Dense(1, activation='linear'))
    model_RNN.compile(loss='mean_squared_error', optimizer='adam')

    return model_RNN

# %% [markdown]
# ## 4. Multilayer Perceptron (MLP)

# %%
def create_mlp(s, neurons, dropout_rate):
    
    input_layer = Input(shape=(s,), dtype='float32')
    dense1 = Dense(neurons, activation='relu')(input_layer)
    dropout_layer = Dropout(dropout_rate)(dense1)
    output_layer = Dense(1, activation='linear')(dropout_layer)

    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %% [markdown]
# ## 5. Long Short Term Memory (LSTM)

# %%
def create_lstm(s, neurons, dropout_rate):

    input_layer = Input(shape=(s, 1), dtype='float32')
    lstm_layer = LSTM(neurons)(input_layer)
    dropout_layer = Dropout(dropout_rate)(lstm_layer)
    output_layer = Dense(1, activation='linear')(dropout_layer)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %% [markdown]
# ## 6. Selección del mejor modelo

# %% [markdown]
# Con la función de activación seleccionada, las funciones de las redes neuronales y conocidos los parámetros que queremos ir combinando de neuronas, drop_out y épocas podemos iniciar el proceso de selección del mejor modelo.

# %% [markdown]
# Para ello fijamos esta primera función _select_model_ con la que guardamos los historiales de procesamiento de modelos en cada época y con la que al final capturamos el mejor modelo generado para esa combinación de parámetros.

# %%
def select_model(model, ep, X_train, y_train, X_val, y_val):

    save_weights_at = os.path.join('keras_models', f'{model.name}_{{epoch:02d}}-{{val_loss:.4f}}.keras')
    save_best = ModelCheckpoint(save_weights_at, monitor='val_loss', verbose=0,
                            save_best_only=True, save_weights_only=False, mode='min', save_freq='epoch');
    
    history_filename = os.path.join('historynn', f'history_{model.name}.joblib')
    history_airp = None

    if os.path.exists(history_filename):
        history_filename = history_filename
        print("El archivo '{history_filename}' ya existe. Se ha cargado el historial del entrenamiento.")
        
    else:
        history_airp = model.fit(x=X_train, y=y_train, batch_size=16, epochs=ep,
                 verbose=2, callbacks=[save_best], validation_data=(X_val, y_val),
                 shuffle=True);
        
        dump(history_airp.history, history_filename)
        print("El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'")

    model_dir = 'keras_models'
    files = os.listdir(model_dir)
    pattern = rf"{re.escape(model.name)}_(\d+)-([\d\.]+)\.keras"
    
    best_val_loss = float('inf')
    best_model_file = None
    best_model = None
    
    for file in files:
        match = re.match(pattern, file)
        if match:
            epoch = int(match.group(1))
            val_loss = float(match.group(2))
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_file = file

    if best_model_file:
        best_model_path = os.path.join(model_dir, best_model_file)
        print(f"Cargando el mejor modelo: {best_model_file} con val_loss: {best_val_loss}")
        best_model = load_model(best_model_path)
    else:
        print("No se encontraron archivos de modelos que coincidan con el patrón.")

    return best_model

# %% [markdown]
# En este ciclo a continuación, fijamos todas las combinaciones de parámetros que deseamos testear, las agregamos a un ciclo que recibe y procesa de acuerdo a cada red neuronal planteada la combinación de parámetros, selecciona el mejor modelo haciendo llamado a la función _select_model_ y al final pronostica tanto validación como testing. Además los score de pronóstico para cada conjunto los calcula y los guarda.

# %%
shape = [3, 4] #Probamos inputs de 3 y 4 datos
neurons = [100, 500, 1000]
ep = [10, 25]
drop_out = [0.2, 0.4, 0.6]
val_result = []
test_result = []

for s in shape:
    
    X_train, y_train = makeXy(train_esc, s+1)
    X_val, y_val = makeXy(val_esc, s+1)
    X_test, y_test = makeXy(test_esc, s+1)
    
    X_valr, y_valr = makeXy(val, s+1)
    X_testr, y_testr = makeXy(test, s+1)
    
    for n in neurons:
        for eph in ep:
            for dpout in drop_out:

                print("Esta combinación es", s, n, eph, dpout)
                
                #creación modelo RNN
                model = create_RNN(n, s, dpout)
                best_model = select_model(model, eph, X_train, y_train, X_val, y_val)

                #validacion
                val_pred = forecast_nw(best_model, X_val) #pronosticar validacion
                mae_v, mape_v, mse_v, rmse_v, r2_v = errors(val_pred, y_valr) #scores validación

                #testing
                test_pred = forecast_nw(best_model, X_test) #pronosticar test
                mae_t, mape_t, mse_t, rmse_t, r2_t = errors(test_pred, y_testr) #scores testing
                
                val_result.append(["rnn", n, eph, dpout, mape_v, mae_v, mse_v, rmse_v, r2_v])
                test_result.append(["rnn", n, eph, dpout, mape_t, mae_t, mse_t, rmse_t, r2_t])

                #creación modelo MLP
                model = create_mlp(s, n, dpout)
                best_model = select_model(model, eph, X_train, y_train, X_val, y_val)

                #validacion
                val_pred = forecast_nw(best_model, X_val) #pronosticar validacion
                mae_v, mape_v, mse_v, rmse_v, r2_v = errors(val_pred, y_valr) #scores validación

                #testing
                test_pred = forecast_nw(best_model, X_test) #pronosticar test
                mae_t, mape_t, mse_t, rmse_t, r2_t = errors(test_pred, y_testr) #scores testing
                
                val_result.append(["mlp", n, eph, dpout, mape_v, mae_v, mse_v, rmse_v, r2_v])
                test_result.append(["mlp", n, eph, dpout, mape_t, mae_t, mse_t, rmse_t, r2_t])

                #creación modelo LSTM
                model = create_lstm(s, n, dpout)
                best_model = select_model(model, eph, X_train, y_train, X_val, y_val)

                #validacion
                val_pred = forecast_nw(best_model, X_val) #pronosticar validacion
                mae_v, mape_v, mse_v, rmse_v, r2_v = errors(val_pred, y_valr) #scores validación

                #testing
                test_pred = forecast_nw(best_model, X_test) #pronosticar test
                mae_t, mape_t, mse_t, rmse_t, r2_t = errors(test_pred, y_testr) #scores testing
                
                val_result.append(["lstm", n, eph, dpout, mape_v, mae_v, mse_v, rmse_v, r2_v])
                test_result.append(["lstm", n, eph, dpout, mape_t, mae_t, mse_t, rmse_t, r2_t])
# Out:
# Esta combinación es 3 100 10 0.2
# Epoch 1/10
# 65/65 - 1s - 23ms/step - loss: 0.0416 - val_loss: 0.0529
# Epoch 2/10
# 65/65 - 0s - 6ms/step - loss: 0.0273 - val_loss: 0.0496
# Epoch 3/10
# 65/65 - 0s - 6ms/step - loss: 0.0265 - val_loss: 0.0492
# Epoch 4/10
# 65/65 - 0s - 6ms/step - loss: 0.0260 - val_loss: 0.0452
# Epoch 5/10
# 65/65 - 0s - 5ms/step - loss: 0.0251 - val_loss: 0.0456
# Epoch 6/10
# 65/65 - 0s - 5ms/step - loss: 0.0258 - val_loss: 0.0469
# Epoch 7/10
# 65/65 - 0s - 5ms/step - loss: 0.0254 - val_loss: 0.0470
# Epoch 8/10
# 65/65 - 0s - 5ms/step - loss: 0.0241 - val_loss: 0.0460
# Epoch 9/10
# 65/65 - 0s - 5ms/step - loss: 0.0247 - val_loss: 0.0458
# Epoch 10/10
# 65/65 - 0s - 5ms/step - loss: 0.0239 - val_loss: 0.0455
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_2_04-0.0452.keras con val_loss: 0.0452
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/10
# 65/65 - 1s - 13ms/step - loss: 0.0548 - val_loss: 0.0745
# Epoch 2/10
# 65/65 - 0s - 4ms/step - loss: 0.0374 - val_loss: 0.0613
# Epoch 3/10
# 65/65 - 0s - 3ms/step - loss: 0.0328 - val_loss: 0.0565
# Epoch 4/10
# 65/65 - 0s - 3ms/step - loss: 0.0291 - val_loss: 0.0533
# Epoch 5/10
# 65/65 - 0s - 3ms/step - loss: 0.0280 - val_loss: 0.0542
# Epoch 6/10
# 65/65 - 0s - 5ms/step - loss: 0.0278 - val_loss: 0.0520
# Epoch 7/10
# 65/65 - 0s - 5ms/step - loss: 0.0272 - val_loss: 0.0498
# Epoch 8/10
# 65/65 - 0s - 5ms/step - loss: 0.0268 - val_loss: 0.0495
# Epoch 9/10
# 65/65 - 0s - 4ms/step - loss: 0.0253 - val_loss: 0.0502
# Epoch 10/10
# 65/65 - 0s - 4ms/step - loss: 0.0255 - val_loss: 0.0504
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_51_08-0.0495.keras con val_loss: 0.0495
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/10
# 65/65 - 2s - 30ms/step - loss: 0.0517 - val_loss: 0.0812
# Epoch 2/10
# 65/65 - 0s - 7ms/step - loss: 0.0416 - val_loss: 0.0702
# Epoch 3/10
# 65/65 - 0s - 7ms/step - loss: 0.0408 - val_loss: 0.0910
# Epoch 4/10
# 65/65 - 0s - 6ms/step - loss: 0.0413 - val_loss: 0.0671
# Epoch 5/10
# 65/65 - 0s - 6ms/step - loss: 0.0414 - val_loss: 0.0726
# Epoch 6/10
# 65/65 - 0s - 6ms/step - loss: 0.0402 - val_loss: 0.0758
# Epoch 7/10
# 65/65 - 0s - 6ms/step - loss: 0.0404 - val_loss: 0.0793
# Epoch 8/10
# 65/65 - 0s - 6ms/step - loss: 0.0413 - val_loss: 0.0728
# Epoch 9/10
# 65/65 - 0s - 7ms/step - loss: 0.0403 - val_loss: 0.0757
# Epoch 10/10
# 65/65 - 0s - 7ms/step - loss: 0.0395 - val_loss: 0.0733
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_52_04-0.0671.keras con val_loss: 0.0671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Esta combinación es 3 100 10 0.4
# Epoch 1/10
# 65/65 - 2s - 24ms/step - loss: 0.0482 - val_loss: 0.0586
# Epoch 2/10
# 65/65 - 0s - 6ms/step - loss: 0.0312 - val_loss: 0.0496
# Epoch 3/10
# 65/65 - 0s - 5ms/step - loss: 0.0290 - val_loss: 0.0526
# Epoch 4/10
# 65/65 - 0s - 6ms/step - loss: 0.0270 - val_loss: 0.0499
# Epoch 5/10
# 65/65 - 0s - 5ms/step - loss: 0.0275 - val_loss: 0.0497
# Epoch 6/10
# 65/65 - 0s - 5ms/step - loss: 0.0260 - val_loss: 0.0500
# Epoch 7/10
# 65/65 - 0s - 5ms/step - loss: 0.0261 - val_loss: 0.0503
# Epoch 8/10
# 65/65 - 0s - 6ms/step - loss: 0.0258 - val_loss: 0.0454
# Epoch 9/10
# 65/65 - 0s - 4ms/step - loss: 0.0265 - val_loss: 0.0450
# Epoch 10/10
# 65/65 - 0s - 5ms/step - loss: 0.0255 - val_loss: 0.0508
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_3_09-0.0450.keras con val_loss: 0.045
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 65/65 - 1s - 15ms/step - loss: 0.0630 - val_loss: 0.0835
# Epoch 2/10
# 65/65 - 1s - 10ms/step - loss: 0.0423 - val_loss: 0.0609
# Epoch 3/10
# 65/65 - 0s - 4ms/step - loss: 0.0362 - val_loss: 0.0554
# Epoch 4/10
# 65/65 - 0s - 4ms/step - loss: 0.0328 - val_loss: 0.0528
# Epoch 5/10
# 65/65 - 0s - 4ms/step - loss: 0.0314 - val_loss: 0.0522
# Epoch 6/10
# 65/65 - 0s - 5ms/step - loss: 0.0308 - val_loss: 0.0516
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0303 - val_loss: 0.0544
# Epoch 8/10
# 65/65 - 0s - 5ms/step - loss: 0.0287 - val_loss: 0.0502
# Epoch 9/10
# 65/65 - 0s - 3ms/step - loss: 0.0286 - val_loss: 0.0503
# Epoch 10/10
# 65/65 - 0s - 3ms/step - loss: 0.0283 - val_loss: 0.0515
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_59_08-0.0502.keras con val_loss: 0.0502
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 65/65 - 2s - 31ms/step - loss: 0.0552 - val_loss: 0.0839
# Epoch 2/10
# 65/65 - 0s - 6ms/step - loss: 0.0426 - val_loss: 0.0740
# Epoch 3/10
# 65/65 - 0s - 7ms/step - loss: 0.0420 - val_loss: 0.0824
# Epoch 4/10
# 65/65 - 0s - 5ms/step - loss: 0.0408 - val_loss: 0.0774
# Epoch 5/10
# 65/65 - 0s - 7ms/step - loss: 0.0408 - val_loss: 0.0741
# Epoch 6/10
# 65/65 - 0s - 8ms/step - loss: 0.0413 - val_loss: 0.0714
# Epoch 7/10
# 65/65 - 0s - 6ms/step - loss: 0.0409 - val_loss: 0.0863
# Epoch 8/10
# 65/65 - 0s - 6ms/step - loss: 0.0409 - val_loss: 0.0801
# Epoch 9/10
# 65/65 - 0s - 6ms/step - loss: 0.0407 - val_loss: 0.0722
# Epoch 10/10
# 65/65 - 0s - 6ms/step - loss: 0.0405 - val_loss: 0.0809
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_60_06-0.0714.keras con val_loss: 0.0714
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Esta combinación es 3 100 10 0.6
# Epoch 1/10
# 65/65 - 2s - 27ms/step - loss: 0.0546 - val_loss: 0.0646
# Epoch 2/10
# 65/65 - 0s - 6ms/step - loss: 0.0374 - val_loss: 0.0553
# Epoch 3/10
# 65/65 - 0s - 5ms/step - loss: 0.0325 - val_loss: 0.0515
# Epoch 4/10
# 65/65 - 0s - 3ms/step - loss: 0.0314 - val_loss: 0.0535
# Epoch 5/10
# 65/65 - 0s - 5ms/step - loss: 0.0289 - val_loss: 0.0532
# Epoch 6/10
# 65/65 - 0s - 6ms/step - loss: 0.0283 - val_loss: 0.0469
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0294 - val_loss: 0.0511
# Epoch 8/10
# 65/65 - 0s - 5ms/step - loss: 0.0275 - val_loss: 0.0478
# Epoch 9/10
# 65/65 - 0s - 6ms/step - loss: 0.0275 - val_loss: 0.0480
# Epoch 10/10
# 65/65 - 0s - 4ms/step - loss: 0.0260 - val_loss: 0.0454
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_4_10-0.0454.keras con val_loss: 0.0454
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/10
# 65/65 - 1s - 13ms/step - loss: 0.0639 - val_loss: 0.0796
# Epoch 2/10
# 65/65 - 0s - 5ms/step - loss: 0.0443 - val_loss: 0.0640
# Epoch 3/10
# 65/65 - 0s - 5ms/step - loss: 0.0360 - val_loss: 0.0582
# Epoch 4/10
# 65/65 - 0s - 4ms/step - loss: 0.0347 - val_loss: 0.0563
# Epoch 5/10
# 65/65 - 0s - 4ms/step - loss: 0.0326 - val_loss: 0.0539
# Epoch 6/10
# 65/65 - 0s - 4ms/step - loss: 0.0320 - val_loss: 0.0517
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0301 - val_loss: 0.0520
# Epoch 8/10
# 65/65 - 0s - 5ms/step - loss: 0.0300 - val_loss: 0.0511
# Epoch 9/10
# 65/65 - 0s - 4ms/step - loss: 0.0289 - val_loss: 0.0534
# Epoch 10/10
# 65/65 - 0s - 4ms/step - loss: 0.0288 - val_loss: 0.0516
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_67_08-0.0511.keras con val_loss: 0.0511
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/10
# 65/65 - 2s - 28ms/step - loss: 0.0569 - val_loss: 0.0864
# Epoch 2/10
# 65/65 - 0s - 7ms/step - loss: 0.0447 - val_loss: 0.0726
# Epoch 3/10
# 65/65 - 0s - 7ms/step - loss: 0.0437 - val_loss: 0.0815
# Epoch 4/10
# 65/65 - 0s - 6ms/step - loss: 0.0418 - val_loss: 0.0720
# Epoch 5/10
# 65/65 - 0s - 6ms/step - loss: 0.0427 - val_loss: 0.0736
# Epoch 6/10
# 65/65 - 0s - 6ms/step - loss: 0.0414 - val_loss: 0.0745
# Epoch 7/10
# 65/65 - 0s - 7ms/step - loss: 0.0423 - val_loss: 0.0893
# Epoch 8/10
# 65/65 - 0s - 6ms/step - loss: 0.0414 - val_loss: 0.0778
# Epoch 9/10
# 65/65 - 0s - 4ms/step - loss: 0.0410 - val_loss: 0.0746
# Epoch 10/10
# 65/65 - 0s - 6ms/step - loss: 0.0411 - val_loss: 0.0760
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_68_04-0.0720.keras con val_loss: 0.072
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Esta combinación es 3 100 25 0.2
# Epoch 1/25
# 65/65 - 1s - 23ms/step - loss: 0.0417 - val_loss: 0.0613
# Epoch 2/25
# 65/65 - 0s - 3ms/step - loss: 0.0280 - val_loss: 0.0497
# Epoch 3/25
# 65/65 - 0s - 4ms/step - loss: 0.0272 - val_loss: 0.0518
# Epoch 4/25
# 65/65 - 0s - 5ms/step - loss: 0.0260 - val_loss: 0.0467
# Epoch 5/25
# 65/65 - 0s - 4ms/step - loss: 0.0257 - val_loss: 0.0480
# Epoch 6/25
# 65/65 - 0s - 4ms/step - loss: 0.0248 - val_loss: 0.0473
# Epoch 7/25
# 65/65 - 0s - 5ms/step - loss: 0.0246 - val_loss: 0.0468
# Epoch 8/25
# 65/65 - 0s - 5ms/step - loss: 0.0250 - val_loss: 0.0504
# Epoch 9/25
# 65/65 - 0s - 4ms/step - loss: 0.0249 - val_loss: 0.0465
# Epoch 10/25
# 65/65 - 0s - 5ms/step - loss: 0.0250 - val_loss: 0.0453
# Epoch 11/25
# 65/65 - 0s - 3ms/step - loss: 0.0246 - val_loss: 0.0457
# Epoch 12/25
# 65/65 - 0s - 5ms/step - loss: 0.0240 - val_loss: 0.0482
# Epoch 13/25
# 65/65 - 0s - 5ms/step - loss: 0.0242 - val_loss: 0.0498
# Epoch 14/25
# 65/65 - 0s - 5ms/step - loss: 0.0242 - val_loss: 0.0475
# Epoch 15/25
# 65/65 - 0s - 4ms/step - loss: 0.0235 - val_loss: 0.0461
# Epoch 16/25
# 65/65 - 0s - 5ms/step - loss: 0.0234 - val_loss: 0.0472
# Epoch 17/25
# 65/65 - 0s - 5ms/step - loss: 0.0240 - val_loss: 0.0484
# Epoch 18/25
# 65/65 - 0s - 6ms/step - loss: 0.0237 - val_loss: 0.0450
# Epoch 19/25
# 65/65 - 0s - 4ms/step - loss: 0.0241 - val_loss: 0.0457
# Epoch 20/25
# 65/65 - 0s - 6ms/step - loss: 0.0231 - val_loss: 0.0445
# Epoch 21/25
# 65/65 - 0s - 6ms/step - loss: 0.0234 - val_loss: 0.0477
# Epoch 22/25
# 65/65 - 0s - 3ms/step - loss: 0.0236 - val_loss: 0.0459
# Epoch 23/25
# 65/65 - 0s - 4ms/step - loss: 0.0232 - val_loss: 0.0468
# Epoch 24/25
# 65/65 - 0s - 5ms/step - loss: 0.0230 - val_loss: 0.0465
# Epoch 25/25
# 65/65 - 0s - 5ms/step - loss: 0.0234 - val_loss: 0.0448
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_5_20-0.0445.keras con val_loss: 0.0445
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/25
# 65/65 - 1s - 14ms/step - loss: 0.0497 - val_loss: 0.0698
# Epoch 2/25
# 65/65 - 0s - 4ms/step - loss: 0.0341 - val_loss: 0.0596
# Epoch 3/25
# 65/65 - 0s - 5ms/step - loss: 0.0305 - val_loss: 0.0519
# Epoch 4/25
# 65/65 - 0s - 5ms/step - loss: 0.0283 - val_loss: 0.0512
# Epoch 5/25
# 65/65 - 0s - 4ms/step - loss: 0.0272 - val_loss: 0.0492
# Epoch 6/25
# 65/65 - 0s - 3ms/step - loss: 0.0261 - val_loss: 0.0496
# Epoch 7/25
# 65/65 - 0s - 5ms/step - loss: 0.0263 - val_loss: 0.0487
# Epoch 8/25
# 65/65 - 0s - 3ms/step - loss: 0.0266 - val_loss: 0.0510
# Epoch 9/25
# 65/65 - 0s - 3ms/step - loss: 0.0260 - val_loss: 0.0518
# Epoch 10/25
# 65/65 - 0s - 5ms/step - loss: 0.0248 - val_loss: 0.0476
# Epoch 11/25
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0484
# Epoch 12/25
# 65/65 - 0s - 3ms/step - loss: 0.0258 - val_loss: 0.0479
# Epoch 13/25
# 65/65 - 0s - 4ms/step - loss: 0.0251 - val_loss: 0.0485
# Epoch 14/25
# 65/65 - 0s - 4ms/step - loss: 0.0247 - val_loss: 0.0480
# Epoch 15/25
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0497
# Epoch 16/25
# 65/65 - 0s - 4ms/step - loss: 0.0245 - val_loss: 0.0475
# Epoch 17/25
# 65/65 - 0s - 3ms/step - loss: 0.0245 - val_loss: 0.0475
# Epoch 18/25
# 65/65 - 0s - 4ms/step - loss: 0.0246 - val_loss: 0.0485
# Epoch 19/25
# 65/65 - 0s - 5ms/step - loss: 0.0243 - val_loss: 0.0474
# Epoch 20/25
# 65/65 - 0s - 3ms/step - loss: 0.0242 - val_loss: 0.0480
# Epoch 21/25
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0483
# Epoch 22/25
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0474
# Epoch 23/25
# 65/65 - 0s - 4ms/step - loss: 0.0245 - val_loss: 0.0478
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0239 - val_loss: 0.0483
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0245 - val_loss: 0.0486
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_75_19-0.0474.keras con val_loss: 0.0474
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/25
# 65/65 - 2s - 29ms/step - loss: 0.0544 - val_loss: 0.0832
# Epoch 2/25
# 65/65 - 0s - 5ms/step - loss: 0.0422 - val_loss: 0.0722
# Epoch 3/25
# 65/65 - 0s - 5ms/step - loss: 0.0412 - val_loss: 0.0727
# Epoch 4/25
# 65/65 - 0s - 7ms/step - loss: 0.0415 - val_loss: 0.0759
# Epoch 5/25
# 65/65 - 0s - 7ms/step - loss: 0.0410 - val_loss: 0.0740
# Epoch 6/25
# 65/65 - 0s - 7ms/step - loss: 0.0406 - val_loss: 0.0833
# Epoch 7/25
# 65/65 - 0s - 6ms/step - loss: 0.0406 - val_loss: 0.0753
# Epoch 8/25
# 65/65 - 0s - 7ms/step - loss: 0.0403 - val_loss: 0.0712
# Epoch 9/25
# 65/65 - 0s - 7ms/step - loss: 0.0406 - val_loss: 0.0852
# Epoch 10/25
# 65/65 - 0s - 7ms/step - loss: 0.0404 - val_loss: 0.0693
# Epoch 11/25
# 65/65 - 0s - 6ms/step - loss: 0.0406 - val_loss: 0.0773
# Epoch 12/25
# 65/65 - 0s - 6ms/step - loss: 0.0395 - val_loss: 0.0743
# Epoch 13/25
# 65/65 - 0s - 6ms/step - loss: 0.0395 - val_loss: 0.0721
# Epoch 14/25
# 65/65 - 0s - 5ms/step - loss: 0.0393 - val_loss: 0.0673
# Epoch 15/25
# 65/65 - 0s - 6ms/step - loss: 0.0395 - val_loss: 0.0758
# Epoch 16/25
# 65/65 - 0s - 6ms/step - loss: 0.0390 - val_loss: 0.0653
# Epoch 17/25
# 65/65 - 0s - 6ms/step - loss: 0.0388 - val_loss: 0.0676
# Epoch 18/25
# 65/65 - 0s - 5ms/step - loss: 0.0375 - val_loss: 0.0695
# Epoch 19/25
# 65/65 - 0s - 7ms/step - loss: 0.0376 - val_loss: 0.0633
# Epoch 20/25
# 65/65 - 0s - 6ms/step - loss: 0.0347 - val_loss: 0.0676
# Epoch 21/25
# 65/65 - 0s - 5ms/step - loss: 0.0333 - val_loss: 0.0573
# Epoch 22/25
# 65/65 - 0s - 3ms/step - loss: 0.0307 - val_loss: 0.0559
# Epoch 23/25
# 65/65 - 0s - 3ms/step - loss: 0.0297 - val_loss: 0.0575
# Epoch 24/25
# 65/65 - 0s - 6ms/step - loss: 0.0295 - val_loss: 0.0512
# Epoch 25/25
# 65/65 - 0s - 7ms/step - loss: 0.0287 - val_loss: 0.0527
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_76_24-0.0512.keras con val_loss: 0.0512
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Esta combinación es 3 100 25 0.4
# Epoch 1/25
# 65/65 - 2s - 24ms/step - loss: 0.0581 - val_loss: 0.0671
# Epoch 2/25
# 65/65 - 0s - 6ms/step - loss: 0.0350 - val_loss: 0.0574
# Epoch 3/25
# 65/65 - 0s - 4ms/step - loss: 0.0303 - val_loss: 0.0570
# Epoch 4/25
# 65/65 - 0s - 4ms/step - loss: 0.0283 - val_loss: 0.0485
# Epoch 5/25
# 65/65 - 0s - 3ms/step - loss: 0.0274 - val_loss: 0.0514
# Epoch 6/25
# 65/65 - 0s - 5ms/step - loss: 0.0257 - val_loss: 0.0471
# Epoch 7/25
# 65/65 - 0s - 5ms/step - loss: 0.0268 - val_loss: 0.0486
# Epoch 8/25
# 65/65 - 0s - 5ms/step - loss: 0.0260 - val_loss: 0.0502
# Epoch 9/25
# 65/65 - 0s - 6ms/step - loss: 0.0262 - val_loss: 0.0451
# Epoch 10/25
# 65/65 - 0s - 5ms/step - loss: 0.0252 - val_loss: 0.0464
# Epoch 11/25
# 65/65 - 0s - 5ms/step - loss: 0.0254 - val_loss: 0.0465
# Epoch 12/25
# 65/65 - 0s - 5ms/step - loss: 0.0257 - val_loss: 0.0463
# Epoch 13/25
# 65/65 - 0s - 5ms/step - loss: 0.0249 - val_loss: 0.0481
# Epoch 14/25
# 65/65 - 0s - 5ms/step - loss: 0.0252 - val_loss: 0.0457
# Epoch 15/25
# 65/65 - 0s - 5ms/step - loss: 0.0253 - val_loss: 0.0458
# Epoch 16/25
# 65/65 - 0s - 6ms/step - loss: 0.0246 - val_loss: 0.0443
# Epoch 17/25
# 65/65 - 0s - 5ms/step - loss: 0.0253 - val_loss: 0.0470
# Epoch 18/25
# 65/65 - 0s - 6ms/step - loss: 0.0240 - val_loss: 0.0457
# Epoch 19/25
# 65/65 - 0s - 5ms/step - loss: 0.0251 - val_loss: 0.0454
# Epoch 20/25
# 65/65 - 0s - 5ms/step - loss: 0.0242 - val_loss: 0.0474
# Epoch 21/25
# 65/65 - 0s - 5ms/step - loss: 0.0242 - val_loss: 0.0467
# Epoch 22/25
# 65/65 - 0s - 5ms/step - loss: 0.0253 - val_loss: 0.0445
# Epoch 23/25
# 65/65 - 0s - 5ms/step - loss: 0.0254 - val_loss: 0.0460
# Epoch 24/25
# 65/65 - 0s - 6ms/step - loss: 0.0240 - val_loss: 0.0463
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0241 - val_loss: 0.0463
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_6_16-0.0443.keras con val_loss: 0.0443
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/25
# 65/65 - 1s - 16ms/step - loss: 0.0512 - val_loss: 0.0662
# Epoch 2/25
# 65/65 - 0s - 5ms/step - loss: 0.0372 - val_loss: 0.0585
# Epoch 3/25
# 65/65 - 0s - 4ms/step - loss: 0.0343 - val_loss: 0.0564
# Epoch 4/25
# 65/65 - 0s - 2ms/step - loss: 0.0318 - val_loss: 0.0523
# Epoch 5/25
# 65/65 - 0s - 3ms/step - loss: 0.0291 - val_loss: 0.0523
# Epoch 6/25
# 65/65 - 0s - 4ms/step - loss: 0.0284 - val_loss: 0.0525
# Epoch 7/25
# 65/65 - 0s - 4ms/step - loss: 0.0279 - val_loss: 0.0515
# Epoch 8/25
# 65/65 - 0s - 3ms/step - loss: 0.0274 - val_loss: 0.0488
# Epoch 9/25
# 65/65 - 0s - 3ms/step - loss: 0.0279 - val_loss: 0.0481
# Epoch 10/25
# 65/65 - 0s - 3ms/step - loss: 0.0274 - val_loss: 0.0484
# Epoch 11/25
# 65/65 - 0s - 4ms/step - loss: 0.0269 - val_loss: 0.0505
# Epoch 12/25
# 65/65 - 0s - 4ms/step - loss: 0.0265 - val_loss: 0.0497
# Epoch 13/25
# 65/65 - 0s - 4ms/step - loss: 0.0263 - val_loss: 0.0492
# Epoch 14/25
# 65/65 - 0s - 4ms/step - loss: 0.0267 - val_loss: 0.0487
# Epoch 15/25
# 65/65 - 0s - 4ms/step - loss: 0.0253 - val_loss: 0.0482
# Epoch 16/25
# 65/65 - 0s - 4ms/step - loss: 0.0253 - val_loss: 0.0493
# Epoch 17/25
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0488
# Epoch 18/25
# 65/65 - 0s - 5ms/step - loss: 0.0253 - val_loss: 0.0479
# Epoch 19/25
# 65/65 - 0s - 3ms/step - loss: 0.0253 - val_loss: 0.0490
# Epoch 20/25
# 65/65 - 0s - 4ms/step - loss: 0.0258 - val_loss: 0.0480
# Epoch 21/25
# 65/65 - 0s - 4ms/step - loss: 0.0263 - val_loss: 0.0488
# Epoch 22/25
# 65/65 - 0s - 4ms/step - loss: 0.0261 - val_loss: 0.0486
# Epoch 23/25
# 65/65 - 0s - 3ms/step - loss: 0.0252 - val_loss: 0.0483
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0251 - val_loss: 0.0478
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0256 - val_loss: 0.0484
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_83_24-0.0478.keras con val_loss: 0.0478
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch 1/25
# 65/65 - 2s - 32ms/step - loss: 0.0551 - val_loss: 0.0804
# Epoch 2/25
# 65/65 - 0s - 6ms/step - loss: 0.0421 - val_loss: 0.0815
# Epoch 3/25
# 65/65 - 0s - 6ms/step - loss: 0.0416 - val_loss: 0.0807
# Epoch 4/25
# 65/65 - 0s - 7ms/step - loss: 0.0414 - val_loss: 0.0852
# Epoch 5/25
# 65/65 - 0s - 7ms/step - loss: 0.0416 - val_loss: 0.0900
# Epoch 6/25
# 65/65 - 0s - 7ms/step - loss: 0.0410 - val_loss: 0.0803
# Epoch 7/25
# 65/65 - 1s - 8ms/step - loss: 0.0406 - val_loss: 0.0781
# Epoch 8/25
# 65/65 - 0s - 6ms/step - loss: 0.0405 - val_loss: 0.0889
# Epoch 9/25
# 65/65 - 0s - 7ms/step - loss: 0.0411 - val_loss: 0.0766
# Epoch 10/25
# 65/65 - 0s - 6ms/step - loss: 0.0412 - val_loss: 0.0800
# Epoch 11/25
# 65/65 - 0s - 7ms/step - loss: 0.0408 - val_loss: 0.0754
# Epoch 12/25
# 65/65 - 0s - 7ms/step - loss: 0.0398 - val_loss: 0.0683
# Epoch 13/25
# 65/65 - 0s - 6ms/step - loss: 0.0405 - val_loss: 0.0711
# Epoch 14/25
# 65/65 - 0s - 7ms/step - loss: 0.0406 - val_loss: 0.0673
# Epoch 15/25
# 65/65 - 0s - 7ms/step - loss: 0.0404 - val_loss: 0.0670
# Epoch 16/25
# 65/65 - 0s - 6ms/step - loss: 0.0400 - val_loss: 0.0741
# Epoch 17/25
# 65/65 - 0s - 6ms/step - loss: 0.0395 - val_loss: 0.0721
# Epoch 18/25
# 65/65 - 0s - 6ms/step - loss: 0.0386 - val_loss: 0.0751
# Epoch 19/25
# 65/65 - 0s - 6ms/step - loss: 0.0385 - val_loss: 0.0662
# Epoch 20/25
# 65/65 - 0s - 7ms/step - loss: 0.0372 - val_loss: 0.0676
# Epoch 21/25
# 65/65 - 0s - 7ms/step - loss: 0.0355 - val_loss: 0.0628
# Epoch 22/25
# 65/65 - 0s - 7ms/step - loss: 0.0341 - val_loss: 0.0562
# Epoch 23/25
# 65/65 - 0s - 7ms/step - loss: 0.0320 - val_loss: 0.0538
# Epoch 24/25
# 65/65 - 0s - 7ms/step - loss: 0.0309 - val_loss: 0.0579
# Epoch 25/25
# 65/65 - 0s - 7ms/step - loss: 0.0301 - val_loss: 0.0572
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_84_23-0.0538.keras con val_loss: 0.0538
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Esta combinación es 3 100 25 0.6
# Epoch 1/25
# 65/65 - 2s - 26ms/step - loss: 0.0554 - val_loss: 0.0602
# Epoch 2/25
# 65/65 - 0s - 6ms/step - loss: 0.0355 - val_loss: 0.0579
# Epoch 3/25
# 65/65 - 0s - 6ms/step - loss: 0.0316 - val_loss: 0.0522
# Epoch 4/25
# 65/65 - 0s - 6ms/step - loss: 0.0298 - val_loss: 0.0519
# Epoch 5/25
# 65/65 - 0s - 6ms/step - loss: 0.0287 - val_loss: 0.0480
# Epoch 6/25
# 65/65 - 0s - 5ms/step - loss: 0.0279 - val_loss: 0.0490
# Epoch 7/25
# 65/65 - 0s - 6ms/step - loss: 0.0283 - val_loss: 0.0475
# Epoch 8/25
# 65/65 - 0s - 6ms/step - loss: 0.0258 - val_loss: 0.0469
# Epoch 9/25
# 65/65 - 0s - 5ms/step - loss: 0.0274 - val_loss: 0.0548
# Epoch 10/25
# 65/65 - 0s - 5ms/step - loss: 0.0256 - val_loss: 0.0473
# Epoch 11/25
# 65/65 - 0s - 5ms/step - loss: 0.0264 - val_loss: 0.0484
# Epoch 12/25
# 65/65 - 0s - 5ms/step - loss: 0.0263 - val_loss: 0.0472
# Epoch 13/25
# 65/65 - 0s - 5ms/step - loss: 0.0260 - val_loss: 0.0464
# Epoch 14/25
# 65/65 - 0s - 6ms/step - loss: 0.0262 - val_loss: 0.0457
# Epoch 15/25
# 65/65 - 0s - 5ms/step - loss: 0.0260 - val_loss: 0.0475
# Epoch 16/25
# 65/65 - 0s - 5ms/step - loss: 0.0246 - val_loss: 0.0465
# Epoch 17/25
# 65/65 - 0s - 5ms/step - loss: 0.0262 - val_loss: 0.0460
# Epoch 18/25
# 65/65 - 0s - 6ms/step - loss: 0.0257 - val_loss: 0.0471
# Epoch 19/25
# 65/65 - 0s - 6ms/step - loss: 0.0247 - val_loss: 0.0451
# Epoch 20/25
# 65/65 - 0s - 4ms/step - loss: 0.0256 - val_loss: 0.0451
# Epoch 21/25
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0453
# Epoch 22/25
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0442
# Epoch 23/25
# 65/65 - 0s - 4ms/step - loss: 0.0256 - val_loss: 0.0454
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0256 - val_loss: 0.0457
# Epoch 25/25
# 65/65 - 0s - 6ms/step - loss: 0.0240 - val_loss: 0.0466
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_7_22-0.0442.keras con val_loss: 0.0442
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/25
# 65/65 - 1s - 14ms/step - loss: 0.0695 - val_loss: 0.0834
# Epoch 2/25
# 65/65 - 0s - 4ms/step - loss: 0.0448 - val_loss: 0.0698
# Epoch 3/25
# 65/65 - 0s - 4ms/step - loss: 0.0379 - val_loss: 0.0609
# Epoch 4/25
# 65/65 - 0s - 4ms/step - loss: 0.0341 - val_loss: 0.0578
# Epoch 5/25
# 65/65 - 0s - 5ms/step - loss: 0.0321 - val_loss: 0.0538
# Epoch 6/25
# 65/65 - 0s - 3ms/step - loss: 0.0310 - val_loss: 0.0548
# Epoch 7/25
# 65/65 - 0s - 4ms/step - loss: 0.0294 - val_loss: 0.0507
# Epoch 8/25
# 65/65 - 0s - 3ms/step - loss: 0.0295 - val_loss: 0.0537
# Epoch 9/25
# 65/65 - 0s - 4ms/step - loss: 0.0284 - val_loss: 0.0510
# Epoch 10/25
# 65/65 - 0s - 4ms/step - loss: 0.0282 - val_loss: 0.0500
# Epoch 11/25
# 65/65 - 0s - 3ms/step - loss: 0.0275 - val_loss: 0.0496
# Epoch 12/25
# 65/65 - 0s - 4ms/step - loss: 0.0270 - val_loss: 0.0496
# Epoch 13/25
# 65/65 - 0s - 4ms/step - loss: 0.0276 - val_loss: 0.0500
# Epoch 14/25
# 65/65 - 0s - 5ms/step - loss: 0.0265 - val_loss: 0.0482
# Epoch 15/25
# 65/65 - 0s - 5ms/step - loss: 0.0264 - val_loss: 0.0475
# Epoch 16/25
# 65/65 - 0s - 4ms/step - loss: 0.0274 - val_loss: 0.0500
# Epoch 17/25
# 65/65 - 0s - 4ms/step - loss: 0.0269 - val_loss: 0.0478
# Epoch 18/25
# 65/65 - 0s - 4ms/step - loss: 0.0277 - val_loss: 0.0485
# Epoch 19/25
# 65/65 - 0s - 4ms/step - loss: 0.0274 - val_loss: 0.0485
# Epoch 20/25
# 65/65 - 0s - 4ms/step - loss: 0.0269 - val_loss: 0.0488
# Epoch 21/25
# 65/65 - 0s - 4ms/step - loss: 0.0270 - val_loss: 0.0489
# Epoch 22/25
# 65/65 - 0s - 4ms/step - loss: 0.0265 - val_loss: 0.0485
# Epoch 23/25
# 65/65 - 0s - 3ms/step - loss: 0.0266 - val_loss: 0.0485
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0261 - val_loss: 0.0489
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0271 - val_loss: 0.0483
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_91_15-0.0475.keras con val_loss: 0.0475
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/25
# 65/65 - 2s - 29ms/step - loss: 0.0539 - val_loss: 0.0780
# Epoch 2/25
# 65/65 - 0s - 7ms/step - loss: 0.0446 - val_loss: 0.0740
# Epoch 3/25
# 65/65 - 0s - 6ms/step - loss: 0.0430 - val_loss: 0.0783
# Epoch 4/25
# 65/65 - 0s - 6ms/step - loss: 0.0420 - val_loss: 0.0885
# Epoch 5/25
# 65/65 - 0s - 6ms/step - loss: 0.0409 - val_loss: 0.0773
# Epoch 6/25
# 65/65 - 0s - 7ms/step - loss: 0.0420 - val_loss: 0.0736
# Epoch 7/25
# 65/65 - 0s - 5ms/step - loss: 0.0418 - val_loss: 0.0772
# Epoch 8/25
# 65/65 - 0s - 7ms/step - loss: 0.0419 - val_loss: 0.0812
# Epoch 9/25
# 65/65 - 0s - 7ms/step - loss: 0.0408 - val_loss: 0.0890
# Epoch 10/25
# 65/65 - 0s - 7ms/step - loss: 0.0414 - val_loss: 0.0734
# Epoch 11/25
# 65/65 - 0s - 4ms/step - loss: 0.0414 - val_loss: 0.0747
# Epoch 12/25
# 65/65 - 0s - 7ms/step - loss: 0.0403 - val_loss: 0.0738
# Epoch 13/25
# 65/65 - 0s - 5ms/step - loss: 0.0408 - val_loss: 0.0717
# Epoch 14/25
# 65/65 - 0s - 4ms/step - loss: 0.0410 - val_loss: 0.0759
# Epoch 15/25
# 65/65 - 0s - 6ms/step - loss: 0.0399 - val_loss: 0.0770
# Epoch 16/25
# 65/65 - 0s - 7ms/step - loss: 0.0407 - val_loss: 0.0757
# Epoch 17/25
# 65/65 - 0s - 7ms/step - loss: 0.0406 - val_loss: 0.0762
# Epoch 18/25
# 65/65 - 0s - 6ms/step - loss: 0.0394 - val_loss: 0.0760
# Epoch 19/25
# 65/65 - 0s - 6ms/step - loss: 0.0390 - val_loss: 0.0732
# Epoch 20/25
# 65/65 - 0s - 6ms/step - loss: 0.0408 - val_loss: 0.0715
# Epoch 21/25
# 65/65 - 0s - 6ms/step - loss: 0.0389 - val_loss: 0.0725
# Epoch 22/25
# 65/65 - 0s - 6ms/step - loss: 0.0389 - val_loss: 0.0732
# Epoch 23/25
# 65/65 - 0s - 7ms/step - loss: 0.0384 - val_loss: 0.0738
# Epoch 24/25
# 65/65 - 0s - 5ms/step - loss: 0.0379 - val_loss: 0.0624
# Epoch 25/25
# 65/65 - 0s - 7ms/step - loss: 0.0363 - val_loss: 0.0579
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_92_25-0.0579.keras con val_loss: 0.0579
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Esta combinación es 3 500 10 0.2
# Epoch 1/10
# 65/65 - 2s - 28ms/step - loss: 0.0354 - val_loss: 0.0507
# Epoch 2/10
# 65/65 - 1s - 11ms/step - loss: 0.0265 - val_loss: 0.0440
# Epoch 3/10
# 65/65 - 1s - 12ms/step - loss: 0.0265 - val_loss: 0.0435
# Epoch 4/10
# 65/65 - 1s - 11ms/step - loss: 0.0253 - val_loss: 0.0523
# Epoch 5/10
# 65/65 - 1s - 10ms/step - loss: 0.0246 - val_loss: 0.0476
# Epoch 6/10
# 65/65 - 1s - 10ms/step - loss: 0.0252 - val_loss: 0.0465
# Epoch 7/10
# 65/65 - 1s - 10ms/step - loss: 0.0237 - val_loss: 0.0467
# Epoch 8/10
# 65/65 - 1s - 10ms/step - loss: 0.0235 - val_loss: 0.0450
# Epoch 9/10
# 65/65 - 1s - 11ms/step - loss: 0.0239 - val_loss: 0.0498
# Epoch 10/10
# 65/65 - 1s - 10ms/step - loss: 0.0237 - val_loss: 0.0450
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_8_03-0.0435.keras con val_loss: 0.0435
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 65/65 - 1s - 16ms/step - loss: 0.0452 - val_loss: 0.0592
# Epoch 2/10
# 65/65 - 0s - 5ms/step - loss: 0.0277 - val_loss: 0.0486
# Epoch 3/10
# 65/65 - 0s - 5ms/step - loss: 0.0253 - val_loss: 0.0480
# Epoch 4/10
# 65/65 - 0s - 4ms/step - loss: 0.0249 - val_loss: 0.0513
# Epoch 5/10
# 65/65 - 0s - 5ms/step - loss: 0.0243 - val_loss: 0.0474
# Epoch 6/10
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0481
# Epoch 7/10
# 65/65 - 0s - 5ms/step - loss: 0.0244 - val_loss: 0.0468
# Epoch 8/10
# 65/65 - 0s - 4ms/step - loss: 0.0240 - val_loss: 0.0482
# Epoch 9/10
# 65/65 - 0s - 4ms/step - loss: 0.0238 - val_loss: 0.0492
# Epoch 10/10
# 65/65 - 0s - 4ms/step - loss: 0.0240 - val_loss: 0.0477
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_99_07-0.0468.keras con val_loss: 0.0468
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/10
# 65/65 - 2s - 38ms/step - loss: 0.0489 - val_loss: 0.0686
# Epoch 2/10
# 65/65 - 1s - 18ms/step - loss: 0.0417 - val_loss: 0.0686
# Epoch 3/10
# 65/65 - 1s - 15ms/step - loss: 0.0404 - val_loss: 0.0822
# Epoch 4/10
# 65/65 - 1s - 17ms/step - loss: 0.0407 - val_loss: 0.0682
# Epoch 5/10
# 65/65 - 1s - 13ms/step - loss: 0.0411 - val_loss: 0.0757
# Epoch 6/10
# 65/65 - 1s - 13ms/step - loss: 0.0410 - val_loss: 0.0847
# Epoch 7/10
# 65/65 - 1s - 13ms/step - loss: 0.0407 - val_loss: 0.0855
# Epoch 8/10
# 65/65 - 1s - 14ms/step - loss: 0.0407 - val_loss: 0.0777
# Epoch 9/10
# 65/65 - 1s - 14ms/step - loss: 0.0410 - val_loss: 0.0672
# Epoch 10/10
# 65/65 - 1s - 15ms/step - loss: 0.0403 - val_loss: 0.0752
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_100_09-0.0672.keras con val_loss: 0.0672
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Esta combinación es 3 500 10 0.4
# Epoch 1/10
# 65/65 - 2s - 29ms/step - loss: 0.0350 - val_loss: 0.0525
# Epoch 2/10
# 65/65 - 1s - 10ms/step - loss: 0.0285 - val_loss: 0.0452
# Epoch 3/10
# 65/65 - 1s - 10ms/step - loss: 0.0259 - val_loss: 0.0503
# Epoch 4/10
# 65/65 - 1s - 10ms/step - loss: 0.0264 - val_loss: 0.0453
# Epoch 5/10
# 65/65 - 1s - 11ms/step - loss: 0.0255 - val_loss: 0.0449
# Epoch 6/10
# 65/65 - 1s - 12ms/step - loss: 0.0248 - val_loss: 0.0448
# Epoch 7/10
# 65/65 - 1s - 10ms/step - loss: 0.0248 - val_loss: 0.0436
# Epoch 8/10
# 65/65 - 1s - 9ms/step - loss: 0.0241 - val_loss: 0.0444
# Epoch 9/10
# 65/65 - 1s - 9ms/step - loss: 0.0245 - val_loss: 0.0461
# Epoch 10/10
# 65/65 - 1s - 9ms/step - loss: 0.0246 - val_loss: 0.0459
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_9_07-0.0436.keras con val_loss: 0.0436
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/10
# 65/65 - 1s - 15ms/step - loss: 0.0492 - val_loss: 0.0626
# Epoch 2/10
# 65/65 - 0s - 4ms/step - loss: 0.0306 - val_loss: 0.0550
# Epoch 3/10
# 65/65 - 0s - 4ms/step - loss: 0.0268 - val_loss: 0.0500
# Epoch 4/10
# 65/65 - 0s - 5ms/step - loss: 0.0259 - val_loss: 0.0477
# Epoch 5/10
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0483
# Epoch 6/10
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0478
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0251 - val_loss: 0.0485
# Epoch 8/10
# 65/65 - 0s - 4ms/step - loss: 0.0251 - val_loss: 0.0487
# Epoch 9/10
# 65/65 - 0s - 5ms/step - loss: 0.0246 - val_loss: 0.0474
# Epoch 10/10
# 65/65 - 0s - 5ms/step - loss: 0.0248 - val_loss: 0.0472
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_107_10-0.0472.keras con val_loss: 0.0472
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 65/65 - 3s - 41ms/step - loss: 0.0480 - val_loss: 0.0699
# Epoch 2/10
# 65/65 - 1s - 16ms/step - loss: 0.0414 - val_loss: 0.0860
# Epoch 3/10
# 65/65 - 1s - 14ms/step - loss: 0.0415 - val_loss: 0.0689
# Epoch 4/10
# 65/65 - 1s - 13ms/step - loss: 0.0412 - val_loss: 0.0814
# Epoch 5/10
# 65/65 - 1s - 14ms/step - loss: 0.0412 - val_loss: 0.0739
# Epoch 6/10
# 65/65 - 1s - 14ms/step - loss: 0.0412 - val_loss: 0.0844
# Epoch 7/10
# 65/65 - 1s - 14ms/step - loss: 0.0414 - val_loss: 0.0693
# Epoch 8/10
# 65/65 - 1s - 13ms/step - loss: 0.0408 - val_loss: 0.0821
# Epoch 9/10
# 65/65 - 1s - 13ms/step - loss: 0.0413 - val_loss: 0.0738
# Epoch 10/10
# 65/65 - 1s - 15ms/step - loss: 0.0407 - val_loss: 0.0746
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_108_03-0.0689.keras con val_loss: 0.0689
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Esta combinación es 3 500 10 0.6
# Epoch 1/10
# 65/65 - 2s - 36ms/step - loss: 0.0412 - val_loss: 0.0489
# Epoch 2/10
# 65/65 - 1s - 10ms/step - loss: 0.0304 - val_loss: 0.0602
# Epoch 3/10
# 65/65 - 1s - 13ms/step - loss: 0.0276 - val_loss: 0.0462
# Epoch 4/10
# 65/65 - 1s - 11ms/step - loss: 0.0270 - val_loss: 0.0503
# Epoch 5/10
# 65/65 - 1s - 10ms/step - loss: 0.0271 - val_loss: 0.0495
# Epoch 6/10
# 65/65 - 1s - 9ms/step - loss: 0.0262 - val_loss: 0.0439
# Epoch 7/10
# 65/65 - 1s - 10ms/step - loss: 0.0260 - val_loss: 0.0462
# Epoch 8/10
# 65/65 - 1s - 11ms/step - loss: 0.0254 - val_loss: 0.0519
# Epoch 9/10
# 65/65 - 0s - 7ms/step - loss: 0.0253 - val_loss: 0.0481
# Epoch 10/10
# 65/65 - 1s - 11ms/step - loss: 0.0247 - val_loss: 0.0554
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_10_06-0.0439.keras con val_loss: 0.0439
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/10
# 65/65 - 1s - 14ms/step - loss: 0.0478 - val_loss: 0.0646
# Epoch 2/10
# 65/65 - 0s - 4ms/step - loss: 0.0312 - val_loss: 0.0600
# Epoch 3/10
# 65/65 - 0s - 4ms/step - loss: 0.0281 - val_loss: 0.0510
# Epoch 4/10
# 65/65 - 0s - 4ms/step - loss: 0.0267 - val_loss: 0.0479
# Epoch 5/10
# 65/65 - 0s - 3ms/step - loss: 0.0262 - val_loss: 0.0506
# Epoch 6/10
# 65/65 - 0s - 5ms/step - loss: 0.0264 - val_loss: 0.0498
# Epoch 7/10
# 65/65 - 0s - 4ms/step - loss: 0.0264 - val_loss: 0.0513
# Epoch 8/10
# 65/65 - 0s - 4ms/step - loss: 0.0271 - val_loss: 0.0476
# Epoch 9/10
# 65/65 - 0s - 2ms/step - loss: 0.0250 - val_loss: 0.0494
# Epoch 10/10
# 65/65 - 0s - 3ms/step - loss: 0.0253 - val_loss: 0.0477
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_115_08-0.0476.keras con val_loss: 0.0476
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/10
# 65/65 - 3s - 41ms/step - loss: 0.0501 - val_loss: 0.0795
# Epoch 2/10
# 65/65 - 1s - 18ms/step - loss: 0.0426 - val_loss: 0.0772
# Epoch 3/10
# 65/65 - 1s - 18ms/step - loss: 0.0419 - val_loss: 0.0714
# Epoch 4/10
# 65/65 - 1s - 17ms/step - loss: 0.0418 - val_loss: 0.0806
# Epoch 5/10
# 65/65 - 1s - 15ms/step - loss: 0.0418 - val_loss: 0.0811
# Epoch 6/10
# 65/65 - 1s - 16ms/step - loss: 0.0413 - val_loss: 0.0675
# Epoch 7/10
# 65/65 - 1s - 13ms/step - loss: 0.0426 - val_loss: 0.0729
# Epoch 8/10
# 65/65 - 1s - 14ms/step - loss: 0.0416 - val_loss: 0.0781
# Epoch 9/10
# 65/65 - 1s - 15ms/step - loss: 0.0409 - val_loss: 0.0695
# Epoch 10/10
# 65/65 - 1s - 14ms/step - loss: 0.0416 - val_loss: 0.0841
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_116_06-0.0675.keras con val_loss: 0.0675
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Esta combinación es 3 500 25 0.2
# Epoch 1/25
# 65/65 - 2s - 33ms/step - loss: 0.0335 - val_loss: 0.0446
# Epoch 2/25
# 65/65 - 1s - 10ms/step - loss: 0.0278 - val_loss: 0.0475
# Epoch 3/25
# 65/65 - 1s - 11ms/step - loss: 0.0250 - val_loss: 0.0439
# Epoch 4/25
# 65/65 - 0s - 7ms/step - loss: 0.0245 - val_loss: 0.0512
# Epoch 5/25
# 65/65 - 1s - 9ms/step - loss: 0.0265 - val_loss: 0.0435
# Epoch 6/25
# 65/65 - 1s - 9ms/step - loss: 0.0245 - val_loss: 0.0507
# Epoch 7/25
# 65/65 - 1s - 9ms/step - loss: 0.0245 - val_loss: 0.0473
# Epoch 8/25
# 65/65 - 1s - 10ms/step - loss: 0.0235 - val_loss: 0.0432
# Epoch 9/25
# 65/65 - 0s - 7ms/step - loss: 0.0244 - val_loss: 0.0480
# Epoch 10/25
# 65/65 - 1s - 10ms/step - loss: 0.0233 - val_loss: 0.0439
# Epoch 11/25
# 65/65 - 1s - 9ms/step - loss: 0.0237 - val_loss: 0.0449
# Epoch 12/25
# 65/65 - 1s - 10ms/step - loss: 0.0237 - val_loss: 0.0476
# Epoch 13/25
# 65/65 - 1s - 9ms/step - loss: 0.0235 - val_loss: 0.0454
# Epoch 14/25
# 65/65 - 1s - 10ms/step - loss: 0.0241 - val_loss: 0.0476
# Epoch 15/25
# 65/65 - 1s - 8ms/step - loss: 0.0234 - val_loss: 0.0452
# Epoch 16/25
# 65/65 - 1s - 8ms/step - loss: 0.0234 - val_loss: 0.0448
# Epoch 17/25
# 65/65 - 1s - 8ms/step - loss: 0.0228 - val_loss: 0.0431
# Epoch 18/25
# 65/65 - 1s - 8ms/step - loss: 0.0230 - val_loss: 0.0462
# Epoch 19/25
# 65/65 - 1s - 10ms/step - loss: 0.0238 - val_loss: 0.0516
# Epoch 20/25
# 65/65 - 1s - 8ms/step - loss: 0.0233 - val_loss: 0.0440
# Epoch 21/25
# 65/65 - 1s - 9ms/step - loss: 0.0229 - val_loss: 0.0454
# Epoch 22/25
# 65/65 - 0s - 8ms/step - loss: 0.0228 - val_loss: 0.0444
# Epoch 23/25
# 65/65 - 0s - 7ms/step - loss: 0.0232 - val_loss: 0.0459
# Epoch 24/25
# 65/65 - 1s - 8ms/step - loss: 0.0235 - val_loss: 0.0437
# Epoch 25/25
# 65/65 - 1s - 8ms/step - loss: 0.0227 - val_loss: 0.0442
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_11_17-0.0431.keras con val_loss: 0.0431
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/25
# 65/65 - 1s - 16ms/step - loss: 0.0435 - val_loss: 0.0526
# Epoch 2/25
# 65/65 - 0s - 4ms/step - loss: 0.0276 - val_loss: 0.0505
# Epoch 3/25
# 65/65 - 0s - 5ms/step - loss: 0.0247 - val_loss: 0.0490
# Epoch 4/25
# 65/65 - 0s - 4ms/step - loss: 0.0243 - val_loss: 0.0521
# Epoch 5/25
# 65/65 - 0s - 5ms/step - loss: 0.0242 - val_loss: 0.0478
# Epoch 6/25
# 65/65 - 0s - 4ms/step - loss: 0.0237 - val_loss: 0.0472
# Epoch 7/25
# 65/65 - 0s - 4ms/step - loss: 0.0242 - val_loss: 0.0486
# Epoch 8/25
# 65/65 - 0s - 5ms/step - loss: 0.0234 - val_loss: 0.0468
# Epoch 9/25
# 65/65 - 0s - 4ms/step - loss: 0.0235 - val_loss: 0.0493
# Epoch 10/25
# 65/65 - 0s - 4ms/step - loss: 0.0238 - val_loss: 0.0474
# Epoch 11/25
# 65/65 - 0s - 4ms/step - loss: 0.0234 - val_loss: 0.0480
# Epoch 12/25
# 65/65 - 0s - 5ms/step - loss: 0.0241 - val_loss: 0.0467
# Epoch 13/25
# 65/65 - 0s - 4ms/step - loss: 0.0241 - val_loss: 0.0471
# Epoch 14/25
# 65/65 - 0s - 4ms/step - loss: 0.0239 - val_loss: 0.0469
# Epoch 15/25
# 65/65 - 0s - 3ms/step - loss: 0.0231 - val_loss: 0.0468
# Epoch 16/25
# 65/65 - 0s - 3ms/step - loss: 0.0231 - val_loss: 0.0475
# Epoch 17/25
# 65/65 - 0s - 5ms/step - loss: 0.0237 - val_loss: 0.0463
# Epoch 18/25
# 65/65 - 0s - 5ms/step - loss: 0.0236 - val_loss: 0.0463
# Epoch 19/25
# 65/65 - 0s - 4ms/step - loss: 0.0234 - val_loss: 0.0481
# Epoch 20/25
# 65/65 - 0s - 5ms/step - loss: 0.0231 - val_loss: 0.0471
# Epoch 21/25
# 65/65 - 0s - 4ms/step - loss: 0.0233 - val_loss: 0.0463
# Epoch 22/25
# 65/65 - 0s - 4ms/step - loss: 0.0234 - val_loss: 0.0466
# Epoch 23/25
# 65/65 - 0s - 5ms/step - loss: 0.0231 - val_loss: 0.0460
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0234 - val_loss: 0.0476
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0231 - val_loss: 0.0463
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_123_23-0.0460.keras con val_loss: 0.046
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/25
# 65/65 - 3s - 40ms/step - loss: 0.0507 - val_loss: 0.0817
# Epoch 2/25
# 65/65 - 1s - 16ms/step - loss: 0.0417 - val_loss: 0.0710
# Epoch 3/25
# 65/65 - 1s - 13ms/step - loss: 0.0416 - val_loss: 0.0727
# Epoch 4/25
# 65/65 - 1s - 13ms/step - loss: 0.0416 - val_loss: 0.0723
# Epoch 5/25
# 65/65 - 1s - 14ms/step - loss: 0.0412 - val_loss: 0.0747
# Epoch 6/25
# 65/65 - 1s - 14ms/step - loss: 0.0410 - val_loss: 0.0909
# Epoch 7/25
# 65/65 - 1s - 14ms/step - loss: 0.0411 - val_loss: 0.0760
# Epoch 8/25
# 65/65 - 1s - 17ms/step - loss: 0.0410 - val_loss: 0.0615
# Epoch 9/25
# 65/65 - 1s - 17ms/step - loss: 0.0409 - val_loss: 0.0763
# Epoch 10/25
# 65/65 - 1s - 14ms/step - loss: 0.0414 - val_loss: 0.0720
# Epoch 11/25
# 65/65 - 1s - 14ms/step - loss: 0.0411 - val_loss: 0.0768
# Epoch 12/25
# 65/65 - 1s - 15ms/step - loss: 0.0399 - val_loss: 0.0723
# Epoch 13/25
# 65/65 - 1s - 14ms/step - loss: 0.0399 - val_loss: 0.0719
# Epoch 14/25
# 65/65 - 1s - 16ms/step - loss: 0.0388 - val_loss: 0.0592
# Epoch 15/25
# 65/65 - 1s - 16ms/step - loss: 0.0339 - val_loss: 0.0568
# Epoch 16/25
# 65/65 - 1s - 15ms/step - loss: 0.0311 - val_loss: 0.0606
# Epoch 17/25
# 65/65 - 1s - 17ms/step - loss: 0.0306 - val_loss: 0.0567
# Epoch 18/25
# 65/65 - 1s - 15ms/step - loss: 0.0303 - val_loss: 0.0470
# Epoch 19/25
# 65/65 - 1s - 17ms/step - loss: 0.0287 - val_loss: 0.0491
# Epoch 20/25
# 65/65 - 1s - 17ms/step - loss: 0.0286 - val_loss: 0.0500
# Epoch 21/25
# 65/65 - 1s - 15ms/step - loss: 0.0278 - val_loss: 0.0491
# Epoch 22/25
# 65/65 - 1s - 11ms/step - loss: 0.0286 - val_loss: 0.0585
# Epoch 23/25
# 65/65 - 1s - 12ms/step - loss: 0.0285 - val_loss: 0.0461
# Epoch 24/25
# 65/65 - 1s - 13ms/step - loss: 0.0279 - val_loss: 0.0481
# Epoch 25/25
# 65/65 - 1s - 16ms/step - loss: 0.0268 - val_loss: 0.0534
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_124_23-0.0461.keras con val_loss: 0.0461
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Esta combinación es 3 500 25 0.4
# Epoch 1/25
# 65/65 - 2s - 31ms/step - loss: 0.0390 - val_loss: 0.0521
# Epoch 2/25
# 65/65 - 1s - 11ms/step - loss: 0.0271 - val_loss: 0.0472
# Epoch 3/25
# 65/65 - 1s - 12ms/step - loss: 0.0255 - val_loss: 0.0465
# Epoch 4/25
# 65/65 - 1s - 11ms/step - loss: 0.0252 - val_loss: 0.0464
# Epoch 5/25
# 65/65 - 1s - 9ms/step - loss: 0.0254 - val_loss: 0.0489
# Epoch 6/25
# 65/65 - 1s - 11ms/step - loss: 0.0257 - val_loss: 0.0445
# Epoch 7/25
# 65/65 - 1s - 11ms/step - loss: 0.0248 - val_loss: 0.0469
# Epoch 8/25
# 65/65 - 1s - 10ms/step - loss: 0.0246 - val_loss: 0.0459
# Epoch 9/25
# 65/65 - 1s - 11ms/step - loss: 0.0244 - val_loss: 0.0446
# Epoch 10/25
# 65/65 - 1s - 8ms/step - loss: 0.0254 - val_loss: 0.0452
# Epoch 11/25
# 65/65 - 1s - 11ms/step - loss: 0.0241 - val_loss: 0.0494
# Epoch 12/25
# 65/65 - 1s - 10ms/step - loss: 0.0251 - val_loss: 0.0455
# Epoch 13/25
# 65/65 - 1s - 11ms/step - loss: 0.0240 - val_loss: 0.0446
# Epoch 14/25
# 65/65 - 0s - 7ms/step - loss: 0.0244 - val_loss: 0.0458
# Epoch 15/25
# 65/65 - 1s - 10ms/step - loss: 0.0234 - val_loss: 0.0474
# Epoch 16/25
# 65/65 - 1s - 9ms/step - loss: 0.0235 - val_loss: 0.0455
# Epoch 17/25
# 65/65 - 1s - 10ms/step - loss: 0.0241 - val_loss: 0.0445
# Epoch 18/25
# 65/65 - 1s - 9ms/step - loss: 0.0235 - val_loss: 0.0503
# Epoch 19/25
# 65/65 - 1s - 10ms/step - loss: 0.0234 - val_loss: 0.0446
# Epoch 20/25
# 65/65 - 1s - 9ms/step - loss: 0.0243 - val_loss: 0.0524
# Epoch 21/25
# 65/65 - 1s - 9ms/step - loss: 0.0238 - val_loss: 0.0452
# Epoch 22/25
# 65/65 - 1s - 10ms/step - loss: 0.0240 - val_loss: 0.0468
# Epoch 23/25
# 65/65 - 1s - 9ms/step - loss: 0.0238 - val_loss: 0.0475
# Epoch 24/25
# 65/65 - 1s - 8ms/step - loss: 0.0237 - val_loss: 0.0463
# Epoch 25/25
# 65/65 - 1s - 8ms/step - loss: 0.0239 - val_loss: 0.0483
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_12_06-0.0445.keras con val_loss: 0.0445
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/25
# 65/65 - 1s - 14ms/step - loss: 0.0473 - val_loss: 0.0600
# Epoch 2/25
# 65/65 - 0s - 5ms/step - loss: 0.0304 - val_loss: 0.0565
# Epoch 3/25
# 65/65 - 0s - 4ms/step - loss: 0.0267 - val_loss: 0.0491
# Epoch 4/25
# 65/65 - 0s - 4ms/step - loss: 0.0259 - val_loss: 0.0502
# Epoch 5/25
# 65/65 - 0s - 4ms/step - loss: 0.0257 - val_loss: 0.0494
# Epoch 6/25
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0479
# Epoch 7/25
# 65/65 - 0s - 5ms/step - loss: 0.0254 - val_loss: 0.0476
# Epoch 8/25
# 65/65 - 0s - 4ms/step - loss: 0.0246 - val_loss: 0.0474
# Epoch 9/25
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0475
# Epoch 10/25
# 65/65 - 0s - 4ms/step - loss: 0.0245 - val_loss: 0.0470
# Epoch 11/25
# 65/65 - 0s - 4ms/step - loss: 0.0250 - val_loss: 0.0496
# Epoch 12/25
# 65/65 - 0s - 4ms/step - loss: 0.0244 - val_loss: 0.0467
# Epoch 13/25
# 65/65 - 0s - 5ms/step - loss: 0.0243 - val_loss: 0.0463
# Epoch 14/25
# 65/65 - 0s - 3ms/step - loss: 0.0246 - val_loss: 0.0470
# Epoch 15/25
# 65/65 - 0s - 4ms/step - loss: 0.0240 - val_loss: 0.0479
# Epoch 16/25
# 65/65 - 0s - 4ms/step - loss: 0.0242 - val_loss: 0.0472
# Epoch 17/25
# 65/65 - 0s - 4ms/step - loss: 0.0243 - val_loss: 0.0470
# Epoch 18/25
# 65/65 - 0s - 4ms/step - loss: 0.0237 - val_loss: 0.0475
# Epoch 19/25
# 65/65 - 0s - 5ms/step - loss: 0.0239 - val_loss: 0.0469
# Epoch 20/25
# 65/65 - 0s - 4ms/step - loss: 0.0236 - val_loss: 0.0465
# Epoch 21/25
# 65/65 - 0s - 5ms/step - loss: 0.0237 - val_loss: 0.0476
# Epoch 22/25
# 65/65 - 0s - 5ms/step - loss: 0.0232 - val_loss: 0.0461
# Epoch 23/25
# 65/65 - 0s - 4ms/step - loss: 0.0239 - val_loss: 0.0467
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0240 - val_loss: 0.0469
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0235 - val_loss: 0.0471
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_131_22-0.0461.keras con val_loss: 0.0461
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/25
# 65/65 - 3s - 39ms/step - loss: 0.0506 - val_loss: 0.0818
# Epoch 2/25
# 65/65 - 1s - 14ms/step - loss: 0.0416 - val_loss: 0.0789
# Epoch 3/25
# 65/65 - 1s - 13ms/step - loss: 0.0416 - val_loss: 0.0900
# Epoch 4/25
# 65/65 - 1s - 15ms/step - loss: 0.0417 - val_loss: 0.0745
# Epoch 5/25
# 65/65 - 1s - 14ms/step - loss: 0.0414 - val_loss: 0.0759
# Epoch 6/25
# 65/65 - 1s - 15ms/step - loss: 0.0409 - val_loss: 0.0778
# Epoch 7/25
# 65/65 - 1s - 15ms/step - loss: 0.0411 - val_loss: 0.0783
# Epoch 8/25
# 65/65 - 1s - 15ms/step - loss: 0.0405 - val_loss: 0.0671
# Epoch 9/25
# 65/65 - 1s - 15ms/step - loss: 0.0420 - val_loss: 0.0849
# Epoch 10/25
# 65/65 - 1s - 14ms/step - loss: 0.0408 - val_loss: 0.0823
# Epoch 11/25
# 65/65 - 1s - 15ms/step - loss: 0.0403 - val_loss: 0.0633
# Epoch 12/25
# 65/65 - 1s - 15ms/step - loss: 0.0394 - val_loss: 0.0802
# Epoch 13/25
# 65/65 - 1s - 16ms/step - loss: 0.0394 - val_loss: 0.0769
# Epoch 14/25
# 65/65 - 1s - 14ms/step - loss: 0.0368 - val_loss: 0.0646
# Epoch 15/25
# 65/65 - 1s - 15ms/step - loss: 0.0326 - val_loss: 0.0577
# Epoch 16/25
# 65/65 - 1s - 16ms/step - loss: 0.0335 - val_loss: 0.0574
# Epoch 17/25
# 65/65 - 1s - 17ms/step - loss: 0.0314 - val_loss: 0.0481
# Epoch 18/25
# 65/65 - 1s - 16ms/step - loss: 0.0301 - val_loss: 0.0556
# Epoch 19/25
# 65/65 - 1s - 16ms/step - loss: 0.0307 - val_loss: 0.0543
# Epoch 20/25
# 65/65 - 1s - 15ms/step - loss: 0.0306 - val_loss: 0.0535
# Epoch 21/25
# 65/65 - 1s - 15ms/step - loss: 0.0290 - val_loss: 0.0485
# Epoch 22/25
# 65/65 - 1s - 17ms/step - loss: 0.0292 - val_loss: 0.0510
# Epoch 23/25
# 65/65 - 1s - 16ms/step - loss: 0.0280 - val_loss: 0.0487
# Epoch 24/25
# 65/65 - 1s - 15ms/step - loss: 0.0276 - val_loss: 0.0537
# Epoch 25/25
# 65/65 - 1s - 15ms/step - loss: 0.0271 - val_loss: 0.0467
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_132_25-0.0467.keras con val_loss: 0.0467
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Esta combinación es 3 500 25 0.6
# Epoch 1/25
# 65/65 - 2s - 35ms/step - loss: 0.0386 - val_loss: 0.0507
# Epoch 2/25
# 65/65 - 1s - 9ms/step - loss: 0.0292 - val_loss: 0.0466
# Epoch 3/25
# 65/65 - 1s - 8ms/step - loss: 0.0284 - val_loss: 0.0558
# Epoch 4/25
# 65/65 - 1s - 9ms/step - loss: 0.0277 - val_loss: 0.0443
# Epoch 5/25
# 65/65 - 1s - 9ms/step - loss: 0.0274 - val_loss: 0.0452
# Epoch 6/25
# 65/65 - 1s - 10ms/step - loss: 0.0269 - val_loss: 0.0436
# Epoch 7/25
# 65/65 - 1s - 8ms/step - loss: 0.0256 - val_loss: 0.0463
# Epoch 8/25
# 65/65 - 1s - 9ms/step - loss: 0.0253 - val_loss: 0.0458
# Epoch 9/25
# 65/65 - 1s - 9ms/step - loss: 0.0269 - val_loss: 0.0459
# Epoch 10/25
# 65/65 - 1s - 8ms/step - loss: 0.0243 - val_loss: 0.0478
# Epoch 11/25
# 65/65 - 1s - 8ms/step - loss: 0.0257 - val_loss: 0.0453
# Epoch 12/25
# 65/65 - 1s - 8ms/step - loss: 0.0245 - val_loss: 0.0429
# Epoch 13/25
# 65/65 - 1s - 8ms/step - loss: 0.0245 - val_loss: 0.0450
# Epoch 14/25
# 65/65 - 1s - 9ms/step - loss: 0.0261 - val_loss: 0.0479
# Epoch 15/25
# 65/65 - 1s - 9ms/step - loss: 0.0250 - val_loss: 0.0478
# Epoch 16/25
# 65/65 - 1s - 10ms/step - loss: 0.0244 - val_loss: 0.0465
# Epoch 17/25
# 65/65 - 1s - 10ms/step - loss: 0.0242 - val_loss: 0.0445
# Epoch 18/25
# 65/65 - 1s - 10ms/step - loss: 0.0239 - val_loss: 0.0451
# Epoch 19/25
# 65/65 - 1s - 9ms/step - loss: 0.0249 - val_loss: 0.0471
# Epoch 20/25
# 65/65 - 1s - 10ms/step - loss: 0.0251 - val_loss: 0.0516
# Epoch 21/25
# 65/65 - 1s - 10ms/step - loss: 0.0243 - val_loss: 0.0458
# Epoch 22/25
# 65/65 - 1s - 8ms/step - loss: 0.0237 - val_loss: 0.0475
# Epoch 23/25
# 65/65 - 1s - 9ms/step - loss: 0.0244 - val_loss: 0.0481
# Epoch 24/25
# 65/65 - 1s - 9ms/step - loss: 0.0245 - val_loss: 0.0443
# Epoch 25/25
# 65/65 - 1s - 10ms/step - loss: 0.0245 - val_loss: 0.0470
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_13_12-0.0429.keras con val_loss: 0.0429
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/25
# ...
# Epoch 25/25
# 65/65 - 1s - 13ms/step - loss: 0.0101 - val_loss: 0.0298
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_35_15-0.0271.keras con val_loss: 0.0271
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/25
# 65/65 - 1s - 13ms/step - loss: 0.0322 - val_loss: 0.0477
# Epoch 2/25
# 65/65 - 0s - 4ms/step - loss: 0.0160 - val_loss: 0.0316
# Epoch 3/25
# 65/65 - 0s - 4ms/step - loss: 0.0129 - val_loss: 0.0297
# Epoch 4/25
# 65/65 - 0s - 4ms/step - loss: 0.0123 - val_loss: 0.0314
# Epoch 5/25
# 65/65 - 0s - 4ms/step - loss: 0.0121 - val_loss: 0.0306
# Epoch 6/25
# 65/65 - 0s - 4ms/step - loss: 0.0121 - val_loss: 0.0348
# Epoch 7/25
# 65/65 - 0s - 4ms/step - loss: 0.0132 - val_loss: 0.0305
# Epoch 8/25
# 65/65 - 0s - 4ms/step - loss: 0.0112 - val_loss: 0.0313
# Epoch 9/25
# 65/65 - 0s - 4ms/step - loss: 0.0111 - val_loss: 0.0309
# Epoch 10/25
# 65/65 - 0s - 4ms/step - loss: 0.0111 - val_loss: 0.0338
# Epoch 11/25
# 65/65 - 0s - 4ms/step - loss: 0.0109 - val_loss: 0.0318
# Epoch 12/25
# 65/65 - 0s - 4ms/step - loss: 0.0108 - val_loss: 0.0304
# Epoch 13/25
# 65/65 - 0s - 4ms/step - loss: 0.0108 - val_loss: 0.0315
# Epoch 14/25
# 65/65 - 0s - 3ms/step - loss: 0.0106 - val_loss: 0.0308
# Epoch 15/25
# 65/65 - 0s - 3ms/step - loss: 0.0107 - val_loss: 0.0333
# Epoch 16/25
# 65/65 - 0s - 3ms/step - loss: 0.0107 - val_loss: 0.0310
# Epoch 17/25
# 65/65 - 0s - 3ms/step - loss: 0.0107 - val_loss: 0.0304
# Epoch 18/25
# 65/65 - 0s - 3ms/step - loss: 0.0110 - val_loss: 0.0311
# Epoch 19/25
# 65/65 - 0s - 3ms/step - loss: 0.0107 - val_loss: 0.0302
# Epoch 20/25
# 65/65 - 0s - 3ms/step - loss: 0.0107 - val_loss: 0.0299
# Epoch 21/25
# 65/65 - 0s - 4ms/step - loss: 0.0108 - val_loss: 0.0298
# Epoch 22/25
# 65/65 - 0s - 4ms/step - loss: 0.0107 - val_loss: 0.0308
# Epoch 23/25
# 65/65 - 0s - 3ms/step - loss: 0.0105 - val_loss: 0.0318
# Epoch 24/25
# 65/65 - 0s - 3ms/step - loss: 0.0106 - val_loss: 0.0304
# Epoch 25/25
# 65/65 - 0s - 5ms/step - loss: 0.0105 - val_loss: 0.0294
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_315_25-0.0294.keras con val_loss: 0.0294
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Epoch 1/25
# 65/65 - 5s - 80ms/step - loss: 0.0515 - val_loss: 0.1060
# Epoch 2/25
# 65/65 - 3s - 42ms/step - loss: 0.0449 - val_loss: 0.0847
# Epoch 3/25
# 65/65 - 3s - 41ms/step - loss: 0.0427 - val_loss: 0.0715
# Epoch 4/25
# 65/65 - 3s - 41ms/step - loss: 0.0408 - val_loss: 0.0740
# Epoch 5/25
# 65/65 - 3s - 43ms/step - loss: 0.0408 - val_loss: 0.0661
# Epoch 6/25
# 65/65 - 3s - 40ms/step - loss: 0.0410 - val_loss: 0.0868
# Epoch 7/25
# 65/65 - 3s - 40ms/step - loss: 0.0400 - val_loss: 0.0804
# Epoch 8/25
# 65/65 - 3s - 41ms/step - loss: 0.0394 - val_loss: 0.0878
# Epoch 9/25
# 65/65 - 3s - 47ms/step - loss: 0.0390 - val_loss: 0.0481
# Epoch 10/25
# 65/65 - 3s - 45ms/step - loss: 0.0397 - val_loss: 0.0661
# Epoch 11/25
# 65/65 - 3s - 46ms/step - loss: 0.0323 - val_loss: 0.0490
# Epoch 12/25
# 65/65 - 3s - 50ms/step - loss: 0.0271 - val_loss: 0.0740
# Epoch 13/25
# 65/65 - 3s - 48ms/step - loss: 0.0246 - val_loss: 0.0425
# Epoch 14/25
# 65/65 - 3s - 41ms/step - loss: 0.0194 - val_loss: 0.0448
# Epoch 15/25
# 65/65 - 3s - 45ms/step - loss: 0.0189 - val_loss: 0.0341
# Epoch 16/25
# 65/65 - 3s - 43ms/step - loss: 0.0171 - val_loss: 0.0447
# Epoch 17/25
# 65/65 - 3s - 44ms/step - loss: 0.0179 - val_loss: 0.0423
# Epoch 18/25
# 65/65 - 3s - 42ms/step - loss: 0.0170 - val_loss: 0.0389
# Epoch 19/25
# 65/65 - 3s - 41ms/step - loss: 0.0165 - val_loss: 0.0369
# Epoch 20/25
# 65/65 - 3s - 43ms/step - loss: 0.0160 - val_loss: 0.0391
# Epoch 21/25
# 65/65 - 3s - 45ms/step - loss: 0.0149 - val_loss: 0.0367
# Epoch 22/25
# 65/65 - 3s - 45ms/step - loss: 0.0163 - val_loss: 0.0356
# Epoch 23/25
# 65/65 - 3s - 50ms/step - loss: 0.0143 - val_loss: 0.0335
# Epoch 24/25
# 65/65 - 3s - 43ms/step - loss: 0.0143 - val_loss: 0.0339
# Epoch 25/25
# 65/65 - 3s - 41ms/step - loss: 0.0164 - val_loss: 0.0399
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_316_23-0.0335.keras con val_loss: 0.0335
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Esta combinación es 4 1000 25 0.4
# Epoch 1/25
# 65/65 - 3s - 39ms/step - loss: 0.0281 - val_loss: 0.0373
# Epoch 2/25
# 65/65 - 1s - 13ms/step - loss: 0.0164 - val_loss: 0.0357
# Epoch 3/25
# 65/65 - 1s - 18ms/step - loss: 0.0165 - val_loss: 0.0301
# Epoch 4/25
# 65/65 - 1s - 16ms/step - loss: 0.0117 - val_loss: 0.0311
# Epoch 5/25
# 65/65 - 1s - 18ms/step - loss: 0.0140 - val_loss: 0.0304
# Epoch 6/25
# 65/65 - 1s - 14ms/step - loss: 0.0151 - val_loss: 0.0323
# Epoch 7/25
# 65/65 - 1s - 20ms/step - loss: 0.0114 - val_loss: 0.0289
# Epoch 8/25
# 65/65 - 1s - 16ms/step - loss: 0.0110 - val_loss: 0.0305
# Epoch 9/25
# 65/65 - 1s - 17ms/step - loss: 0.0118 - val_loss: 0.0366
# Epoch 10/25
# 65/65 - 1s - 12ms/step - loss: 0.0114 - val_loss: 0.0317
# Epoch 11/25
# 65/65 - 1s - 18ms/step - loss: 0.0115 - val_loss: 0.0303
# Epoch 12/25
# 65/65 - 1s - 15ms/step - loss: 0.0119 - val_loss: 0.0287
# Epoch 13/25
# 65/65 - 1s - 16ms/step - loss: 0.0112 - val_loss: 0.0301
# Epoch 14/25
# 65/65 - 1s - 13ms/step - loss: 0.0108 - val_loss: 0.0307
# Epoch 15/25
# 65/65 - 1s - 18ms/step - loss: 0.0105 - val_loss: 0.0316
# Epoch 16/25
# 65/65 - 1s - 15ms/step - loss: 0.0112 - val_loss: 0.0290
# Epoch 17/25
# 65/65 - 1s - 16ms/step - loss: 0.0104 - val_loss: 0.0366
# Epoch 18/25
# 65/65 - 1s - 16ms/step - loss: 0.0114 - val_loss: 0.0308
# Epoch 19/25
# 65/65 - 1s - 14ms/step - loss: 0.0105 - val_loss: 0.0283
# Epoch 20/25
# 65/65 - 1s - 16ms/step - loss: 0.0104 - val_loss: 0.0361
# Epoch 21/25
# 65/65 - 1s - 13ms/step - loss: 0.0112 - val_loss: 0.0297
# Epoch 22/25
# 65/65 - 1s - 15ms/step - loss: 0.0103 - val_loss: 0.0288
# Epoch 23/25
# 65/65 - 1s - 16ms/step - loss: 0.0102 - val_loss: 0.0297
# Epoch 24/25
# 65/65 - 1s - 17ms/step - loss: 0.0099 - val_loss: 0.0288
# Epoch 25/25
# 65/65 - 1s - 15ms/step - loss: 0.0098 - val_loss: 0.0323
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_36_19-0.0283.keras con val_loss: 0.0283
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/25
# 65/65 - 1s - 14ms/step - loss: 0.0388 - val_loss: 0.0411
# Epoch 2/25
# 65/65 - 0s - 5ms/step - loss: 0.0179 - val_loss: 0.0305
# Epoch 3/25
# 65/65 - 0s - 5ms/step - loss: 0.0138 - val_loss: 0.0298
# Epoch 4/25
# 65/65 - 0s - 4ms/step - loss: 0.0124 - val_loss: 0.0304
# Epoch 5/25
# 65/65 - 0s - 4ms/step - loss: 0.0141 - val_loss: 0.0312
# Epoch 6/25
# 65/65 - 0s - 4ms/step - loss: 0.0127 - val_loss: 0.0306
# Epoch 7/25
# 65/65 - 0s - 4ms/step - loss: 0.0116 - val_loss: 0.0324
# Epoch 8/25
# 65/65 - 0s - 4ms/step - loss: 0.0121 - val_loss: 0.0331
# Epoch 9/25
# 65/65 - 0s - 4ms/step - loss: 0.0120 - val_loss: 0.0314
# Epoch 10/25
# 65/65 - 0s - 3ms/step - loss: 0.0113 - val_loss: 0.0319
# Epoch 11/25
# 65/65 - 0s - 2ms/step - loss: 0.0117 - val_loss: 0.0306
# Epoch 12/25
# 65/65 - 0s - 3ms/step - loss: 0.0118 - val_loss: 0.0320
# Epoch 13/25
# 65/65 - 0s - 2ms/step - loss: 0.0116 - val_loss: 0.0304
# Epoch 14/25
# 65/65 - 0s - 4ms/step - loss: 0.0111 - val_loss: 0.0312
# Epoch 15/25
# 65/65 - 0s - 3ms/step - loss: 0.0109 - val_loss: 0.0311
# Epoch 16/25
# 65/65 - 0s - 3ms/step - loss: 0.0113 - val_loss: 0.0302
# Epoch 17/25
# 65/65 - 0s - 3ms/step - loss: 0.0115 - val_loss: 0.0313
# Epoch 18/25
# 65/65 - 0s - 3ms/step - loss: 0.0112 - val_loss: 0.0313
# Epoch 19/25
# 65/65 - 0s - 3ms/step - loss: 0.0118 - val_loss: 0.0313
# Epoch 20/25
# 65/65 - 0s - 3ms/step - loss: 0.0116 - val_loss: 0.0310
# Epoch 21/25
# 65/65 - 0s - 3ms/step - loss: 0.0112 - val_loss: 0.0318
# Epoch 22/25
# 65/65 - 0s - 3ms/step - loss: 0.0113 - val_loss: 0.0305
# Epoch 23/25
# 65/65 - 0s - 3ms/step - loss: 0.0113 - val_loss: 0.0318
# Epoch 24/25
# 65/65 - 0s - 4ms/step - loss: 0.0112 - val_loss: 0.0326
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0109 - val_loss: 0.0302
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_323_03-0.0298.keras con val_loss: 0.0298
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/25
# 65/65 - 4s - 66ms/step - loss: 0.0492 - val_loss: 0.0631
# Epoch 2/25
# 65/65 - 3s - 39ms/step - loss: 0.0435 - val_loss: 0.1212
# Epoch 3/25
# 65/65 - 3s - 41ms/step - loss: 0.0443 - val_loss: 0.0803
# Epoch 4/25
# 65/65 - 3s - 41ms/step - loss: 0.0428 - val_loss: 0.0848
# Epoch 5/25
# 65/65 - 3s - 41ms/step - loss: 0.0407 - val_loss: 0.1002
# Epoch 6/25
# 65/65 - 3s - 41ms/step - loss: 0.0409 - val_loss: 0.0782
# Epoch 7/25
# 65/65 - 3s - 45ms/step - loss: 0.0416 - val_loss: 0.0713
# Epoch 8/25
# 65/65 - 3s - 44ms/step - loss: 0.0406 - val_loss: 0.0714
# Epoch 9/25
# 65/65 - 3s - 51ms/step - loss: 0.0403 - val_loss: 0.0577
# Epoch 10/25
# 65/65 - 5s - 71ms/step - loss: 0.0399 - val_loss: 0.0838
# Epoch 11/25
# 65/65 - 5s - 76ms/step - loss: 0.0391 - val_loss: 0.0685
# Epoch 12/25
# 65/65 - 5s - 83ms/step - loss: 0.0368 - val_loss: 0.0454
# Epoch 13/25
# 65/65 - 5s - 84ms/step - loss: 0.0333 - val_loss: 0.0534
# Epoch 14/25
# 65/65 - 5s - 71ms/step - loss: 0.0283 - val_loss: 0.0691
# Epoch 15/25
# 65/65 - 6s - 97ms/step - loss: 0.0304 - val_loss: 0.0485
# Epoch 16/25
# 65/65 - 5s - 74ms/step - loss: 0.0225 - val_loss: 0.0561
# Epoch 17/25
# 65/65 - 5s - 73ms/step - loss: 0.0230 - val_loss: 0.0415
# Epoch 18/25
# 65/65 - 5s - 82ms/step - loss: 0.0213 - val_loss: 0.0367
# Epoch 19/25
# 65/65 - 6s - 100ms/step - loss: 0.0186 - val_loss: 0.0345
# Epoch 20/25
# 65/65 - 5s - 73ms/step - loss: 0.0175 - val_loss: 0.0381
# Epoch 21/25
# 65/65 - 4s - 65ms/step - loss: 0.0170 - val_loss: 0.0382
# Epoch 22/25
# 65/65 - 5s - 70ms/step - loss: 0.0181 - val_loss: 0.0317
# Epoch 23/25
# 65/65 - 5s - 84ms/step - loss: 0.0169 - val_loss: 0.0354
# Epoch 24/25
# 65/65 - 5s - 77ms/step - loss: 0.0167 - val_loss: 0.0410
# Epoch 25/25
# 65/65 - 4s - 64ms/step - loss: 0.0172 - val_loss: 0.0326
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_324_22-0.0317.keras con val_loss: 0.0317
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Esta combinación es 4 1000 25 0.6
# Epoch 1/25
# 65/65 - 5s - 77ms/step - loss: 0.0280 - val_loss: 0.0424
# Epoch 2/25
# 65/65 - 2s - 26ms/step - loss: 0.0204 - val_loss: 0.0360
# Epoch 3/25
# 65/65 - 1s - 21ms/step - loss: 0.0154 - val_loss: 0.0334
# Epoch 4/25
# 65/65 - 1s - 22ms/step - loss: 0.0152 - val_loss: 0.0306
# Epoch 5/25
# 65/65 - 1s - 20ms/step - loss: 0.0143 - val_loss: 0.0328
# Epoch 6/25
# 65/65 - 1s - 20ms/step - loss: 0.0132 - val_loss: 0.0312
# Epoch 7/25
# 65/65 - 1s - 22ms/step - loss: 0.0121 - val_loss: 0.0317
# Epoch 8/25
# 65/65 - 1s - 21ms/step - loss: 0.0128 - val_loss: 0.0374
# Epoch 9/25
# 65/65 - 1s - 20ms/step - loss: 0.0131 - val_loss: 0.0376
# Epoch 10/25
# 65/65 - 1s - 21ms/step - loss: 0.0117 - val_loss: 0.0293
# Epoch 11/25
# 65/65 - 2s - 24ms/step - loss: 0.0125 - val_loss: 0.0341
# Epoch 12/25
# 65/65 - 1s - 21ms/step - loss: 0.0123 - val_loss: 0.0295
# Epoch 13/25
# 65/65 - 1s - 20ms/step - loss: 0.0122 - val_loss: 0.0317
# Epoch 14/25
# 65/65 - 1s - 23ms/step - loss: 0.0117 - val_loss: 0.0286
# Epoch 15/25
# 65/65 - 1s - 21ms/step - loss: 0.0125 - val_loss: 0.0287
# Epoch 16/25
# 65/65 - 2s - 35ms/step - loss: 0.0117 - val_loss: 0.0279
# Epoch 17/25
# 65/65 - 2s - 38ms/step - loss: 0.0116 - val_loss: 0.0312
# Epoch 18/25
# 65/65 - 2s - 35ms/step - loss: 0.0108 - val_loss: 0.0322
# Epoch 19/25
# 65/65 - 1s - 21ms/step - loss: 0.0111 - val_loss: 0.0276
# Epoch 20/25
# 65/65 - 1s - 20ms/step - loss: 0.0114 - val_loss: 0.0285
# Epoch 21/25
# 65/65 - 1s - 21ms/step - loss: 0.0115 - val_loss: 0.0301
# Epoch 22/25
# 65/65 - 1s - 20ms/step - loss: 0.0104 - val_loss: 0.0301
# Epoch 23/25
# 65/65 - 1s - 21ms/step - loss: 0.0114 - val_loss: 0.0287
# Epoch 24/25
# 65/65 - 2s - 24ms/step - loss: 0.0118 - val_loss: 0.0303
# Epoch 25/25
# 65/65 - 2s - 31ms/step - loss: 0.0109 - val_loss: 0.0283
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_37_19-0.0276.keras con val_loss: 0.0276
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 1/25
# 65/65 - 2s - 28ms/step - loss: 0.0386 - val_loss: 0.0438
# Epoch 2/25
# 65/65 - 0s - 8ms/step - loss: 0.0206 - val_loss: 0.0319
# Epoch 3/25
# 65/65 - 1s - 9ms/step - loss: 0.0160 - val_loss: 0.0301
# Epoch 4/25
# 65/65 - 0s - 7ms/step - loss: 0.0138 - val_loss: 0.0301
# Epoch 5/25
# 65/65 - 0s - 7ms/step - loss: 0.0133 - val_loss: 0.0308
# Epoch 6/25
# 65/65 - 0s - 7ms/step - loss: 0.0133 - val_loss: 0.0301
# Epoch 7/25
# 65/65 - 1s - 10ms/step - loss: 0.0125 - val_loss: 0.0316
# Epoch 8/25
# 65/65 - 1s - 8ms/step - loss: 0.0122 - val_loss: 0.0314
# Epoch 9/25
# 65/65 - 0s - 5ms/step - loss: 0.0122 - val_loss: 0.0321
# Epoch 10/25
# 65/65 - 0s - 6ms/step - loss: 0.0133 - val_loss: 0.0303
# Epoch 11/25
# 65/65 - 0s - 5ms/step - loss: 0.0126 - val_loss: 0.0311
# Epoch 12/25
# 65/65 - 0s - 6ms/step - loss: 0.0116 - val_loss: 0.0310
# Epoch 13/25
# 65/65 - 0s - 5ms/step - loss: 0.0120 - val_loss: 0.0318
# Epoch 14/25
# 65/65 - 0s - 5ms/step - loss: 0.0126 - val_loss: 0.0318
# Epoch 15/25
# 65/65 - 0s - 5ms/step - loss: 0.0124 - val_loss: 0.0308
# Epoch 16/25
# 65/65 - 0s - 6ms/step - loss: 0.0129 - val_loss: 0.0317
# Epoch 17/25
# 65/65 - 0s - 5ms/step - loss: 0.0129 - val_loss: 0.0312
# Epoch 18/25
# 65/65 - 0s - 5ms/step - loss: 0.0119 - val_loss: 0.0312
# Epoch 19/25
# 65/65 - 0s - 6ms/step - loss: 0.0119 - val_loss: 0.0311
# Epoch 20/25
# 65/65 - 0s - 5ms/step - loss: 0.0125 - val_loss: 0.0349
# Epoch 21/25
# 65/65 - 0s - 7ms/step - loss: 0.0116 - val_loss: 0.0320
# Epoch 22/25
# 65/65 - 0s - 6ms/step - loss: 0.0122 - val_loss: 0.0323
# Epoch 23/25
# 65/65 - 1s - 9ms/step - loss: 0.0123 - val_loss: 0.0304
# Epoch 24/25
# 65/65 - 1s - 9ms/step - loss: 0.0122 - val_loss: 0.0309
# Epoch 25/25
# 65/65 - 0s - 6ms/step - loss: 0.0122 - val_loss: 0.0304
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_331_03-0.0301.keras con val_loss: 0.0301
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 1/25
# 65/65 - 7s - 104ms/step - loss: 0.0515 - val_loss: 0.0721
# Epoch 2/25
# 65/65 - 4s - 67ms/step - loss: 0.0428 - val_loss: 0.0728
# Epoch 3/25
# 65/65 - 4s - 64ms/step - loss: 0.0426 - val_loss: 0.0737
# Epoch 4/25
# 65/65 - 4s - 68ms/step - loss: 0.0426 - val_loss: 0.0748
# Epoch 5/25
# 65/65 - 5s - 71ms/step - loss: 0.0409 - val_loss: 0.0916
# Epoch 6/25
# 65/65 - 7s - 102ms/step - loss: 0.0419 - val_loss: 0.0960
# Epoch 7/25
# 65/65 - 7s - 111ms/step - loss: 0.0412 - val_loss: 0.0502
# Epoch 8/25
# 65/65 - 6s - 90ms/step - loss: 0.0415 - val_loss: 0.0736
# Epoch 9/25
# 65/65 - 6s - 89ms/step - loss: 0.0416 - val_loss: 0.0646
# Epoch 10/25
# 65/65 - 6s - 95ms/step - loss: 0.0402 - val_loss: 0.0708
# Epoch 11/25
# 65/65 - 5s - 84ms/step - loss: 0.0391 - val_loss: 0.0704
# Epoch 12/25
# 65/65 - 6s - 88ms/step - loss: 0.0417 - val_loss: 0.0775
# Epoch 13/25
# 65/65 - 6s - 86ms/step - loss: 0.0394 - val_loss: 0.0684
# Epoch 14/25
# 65/65 - 6s - 95ms/step - loss: 0.0336 - val_loss: 0.0766
# Epoch 15/25
# 65/65 - 6s - 87ms/step - loss: 0.0322 - val_loss: 0.0524
# Epoch 16/25
# 65/65 - 6s - 85ms/step - loss: 0.0282 - val_loss: 0.0702
# Epoch 17/25
# 65/65 - 5s - 79ms/step - loss: 0.0270 - val_loss: 0.0363
# Epoch 18/25
# 65/65 - 4s - 66ms/step - loss: 0.0240 - val_loss: 0.0505
# Epoch 19/25
# 65/65 - 4s - 66ms/step - loss: 0.0241 - val_loss: 0.0438
# Epoch 20/25
# 65/65 - 4s - 67ms/step - loss: 0.0204 - val_loss: 0.0388
# Epoch 21/25
# 65/65 - 4s - 65ms/step - loss: 0.0198 - val_loss: 0.0396
# Epoch 22/25
# 65/65 - 6s - 92ms/step - loss: 0.0182 - val_loss: 0.0374
# Epoch 23/25
# 65/65 - 6s - 92ms/step - loss: 0.0193 - val_loss: 0.0348
# Epoch 24/25
# 65/65 - 6s - 92ms/step - loss: 0.0195 - val_loss: 0.0396
# Epoch 25/25
# 65/65 - 6s - 97ms/step - loss: 0.0237 - val_loss: 0.0358
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: functional_332_23-0.0348.keras con val_loss: 0.0348
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %% [markdown]
# Son 36 combinaciones de parámetros cada una evaluada para 3 modelos de redes neuronales, hemos generado 108 modelos y es momento de analizar el desempeño de cada uno de estos.

# %%
len(val_result)
# Out:
# 108

# %% [markdown]
# Exportaremos estos resultados para guardarlos junto a los demás resultados de los otros modelos.

# %%
dfval = pd.DataFrame(val_result, columns=['model', 'neurons', 'epochs', 'dropout', 'mape', 'mae', 'mse', 'rmse', 'r2'])
dftest = pd.DataFrame(test_result, columns=['model', 'neurons', 'epochs', 'dropout', 'mape', 'mae', 'mse', 'rmse', 'r2'])

# %%
dftest.to_excel("results/nwtest.xlsx")
dfval.to_excel("results/nwval.xlsx")

# %% [markdown]
# ## 7. Análisis de resultados

# %% [markdown]
# Analicemos a continuación el comportamiento del MAE con respecto a los parámetros y modelo utilizado. Así como el desempeño de las redes neuronales durante el testing.

# %% [markdown]
# ### 7.1 Entrenamiento: Modelos y Parámetros

# %% [markdown]
# Observemos la distribución del MAE para los 3 tipos de redes neuronales analizados.

# %%
dfval.boxplot(column='mae', by='model', grid=False, patch_artist=True)
plt.title('Distribución del MAE por Tipo de Modelo')
plt.suptitle('')
plt.xlabel('Tipo de Modelo')
plt.ylabel('MAE')
plt.show()

# %% [markdown]
# **Key insights**
# 1. El modelo LSTM presentó el mayor MAE registrado en las corridas del algoritmo, de hecho en el 50% de los casos tiene 16 unidades de MAE o más, esto es menor que lo alcanzado incluso con el modelo ARIMA del capítulo anterior y la suavización exponencial simple. Importante considerar que en los parámetros de la LSTM no utilizamos la función de activación RELU que sí consideramos para el modelo MLP y RNN.
# 2. El primer puesto lo ocupó la red neuronal RNN, que alcanzó el valor mínimo entre los 3 modelos, de hecho su valor máximo está todavía por debajo del modelo MLP. En el 50% de los casos tiene aproximadamente menos de 12 unidades de MAE, la mejor mediana entre los 3 modelos.

# %% [markdown]
# Ahora con respecto a los parámetros utilizados dentro del modelo, podemos observar lo siguiente:

# %%
mae_neurons = dfval.groupby('neurons')['mae'].mean().reset_index()
mae_dropout = dfval.groupby('dropout')['mae'].mean().reset_index()
mae_epochs = dfval.groupby('epochs')['mae'].mean().reset_index()

plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt.bar(mae_neurons['neurons'].astype(str), mae_neurons['mae'], color='skyblue')
plt.title('MAE Promedio por Número de Neuronas')
plt.xlabel('Número de Neuronas')
plt.ylabel('MAE Promedio')

plt.subplot(1, 3, 2)
plt.bar(mae_dropout['dropout'].astype(str), mae_dropout['mae'], color='lightgreen')
plt.title('MAE Promedio por Dropout')
plt.xlabel('Tasa de Dropout')
plt.ylabel('MAE Promedio')

plt.subplot(1, 3, 3)
plt.bar(mae_epochs['epochs'].astype(str), mae_epochs['mae'], color='salmon')
plt.title('MAE Promedio por Número de Épocas')
plt.xlabel('Número de Épocas')
plt.ylabel('MAE Promedio')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Key insights**
# 1. Con respecto a las neuronas, se observa que a medida que se incrementó el valor se consiguió un mejor MAE, sin embargo la diferencia es mínimo entre 500 y 1000 neuronas, para optimizar el código se pueden dejar solo 500 y se reducen el número de combinaciones para evaluar.
# 2. Con respecto al dropout observamos que a medida que aumentamos la tasa, aumenta el MAE, podríamos buscar probar una tasa de 0.1 en evaluaciones posteriores para conocer si esto mejora el desempeño del modelo.
# 3. Con respecto al número de épocas el desempeñó sí presentó una alta variación, de hecho cuando se usaron 25 épocas el MAE disminuó casi 2 unidades en promedio, por lo que quisiéramos probar en otra ocasión un número de épocas mayor y conocer si eso mejora el desempeño.

# %% [markdown]
# ### 7.2 Top 15 mejores MAE en el conjunto de testing

# %% [markdown]
# Analicemos ahora los modelos que alcanzaron el mejor MAE en el testing, sus pronósticos y el tipo de modelo.

# %%
dftest.boxplot(column='mae', by='model', grid=False, patch_artist=True)
plt.title('Distribución del MAE por Tipo de Modelo')
plt.suptitle('')
plt.xlabel('Tipo de Modelo')
plt.ylabel('MAE')
plt.show()

# %% [markdown]
# **Key insights**
# 1. En el test se mantuvo el mismo podio, sin embargo la red LSTM mejoró su resultado MAE promedio.
# 2. La RNN emparejó más sus resultados con la red MLP, sin embargo obtuvo de nuevo el menor valor MAE registrado. En el 50% de los conjuntos de test que pronosticó, de hecho, obtuvo un valor cercano a 10 unidades, mientras que la MLP un valor por encima de 11.

# %%
dftest.sort_values("mae",ascending = True).head(15)
# Out:
#    model  neurons  epochs  dropout  mape       mae         mse       rmse  \
# 69   rnn      100      25      0.6   inf  7.464502  113.344922  10.646357
# 91   mlp     1000      10      0.2   inf  7.573771  112.843935  10.622803
# 75   rnn      500      10      0.4   inf  7.791840  126.241094  11.235706
# 96   rnn     1000      10      0.6   inf  7.800657  123.804271  11.126737
# 84   rnn      500      25      0.4   inf  7.845781  128.819801  11.349881
# 76   mlp      500      10      0.4   inf  7.956229  121.193801  11.008806
# 54   rnn      100      10      0.2   inf  7.956674  129.640784  11.385991
# 78   rnn      500      10      0.6   inf  8.029625  125.188040  11.188746
# 63   rnn      100      25      0.2   inf  8.034240  134.584676  11.601064
# 79   mlp      500      10      0.6   inf  8.057249  123.130328  11.096411
# 99   rnn     1000      25      0.2   inf  8.063574  137.441519  11.723545
# 97   mlp     1000      10      0.6   inf  8.105024  124.115713  11.140723
# 73   mlp      500      10      0.2   inf  8.115881  124.646327  11.164512
# 66   rnn      100      25      0.4   inf  8.126293  134.891361  11.614274
# 81   rnn      500      25      0.2   inf  8.130408  139.624596  11.816285
#
#           r2
# 69  0.683541
# 91  0.684940
# 75  0.647535
# 96  0.654339
# 84  0.640336
# 76  0.661627
# 54  0.638043
# 78  0.650476
# 63  0.624240
# 79  0.656221
# 99  0.616264
# 97  0.653469
# 73  0.651988
# 66  0.623384
# 81  0.610169

# %% [markdown]
# **Key insights Top 15**
# 1. El mejor MAE fue de 7.46 unidades con el modelo RNN, casi un 50% menos que el conseguido con ARIMA en el capítulo anterior. Además aumentó el R2 a 68% ante 23% que presentó ARIMA.
# 2. En segundo lugar se alcanzó un MAE de 7.57 unidades, en este caso con el modelo MLP, que de hecho presenta un mejor R2 que la serie RNN, es decir logró capturar un poco mejor la variabilidad de la respuesta.
# 3. Ahora si observamos el top 15 de mejores modelos, podemos observar que no hay ningún caso en el que se encuentre el modelo LSTM. De hecho el 66% de los modelos que están en este top fueron calculados a partir de RNN.
# 4. Curiosamente mejor modelo tiene parámetros 100 neuronas, 25 épocas y 0.6 de drop-out, lo que no coincide con el análisis del entrenamiento, en donde 100 neuronas y 0.6 de drop-out estaba relacionado con los menores MAE.
# 5. En esta tabla no se observa, pero **la partición mejoró cuando se usaban 4 datos como input layer**.

# %% [markdown]
# ### 7.3 Pronóstico con el mejor modelo

# %%
s = 4
X_train, y_train = makeXy(train_esc, s+1)
X_val, y_val = makeXy(val_esc, s+1)
X_test, y_test = makeXy(test_esc, s+1)
    
X_valr, y_valr = makeXy(val, s+1)
X_testr, y_testr = makeXy(test, s+1)

# %%
model = create_RNN(100, s, 0.6)
best_model = select_model(model, eph, X_train, y_train, X_val, y_val)

val_pred = forecast_nw(best_model, X_val)
test_pred = forecast_nw(best_model, X_test)
# Out:
# Epoch 1/25
# 65/65 - 2s - 25ms/step - loss: 0.0494 - val_loss: 0.0498
# Epoch 2/25
# 65/65 - 0s - 6ms/step - loss: 0.0283 - val_loss: 0.0447
# Epoch 3/25
# 65/65 - 0s - 6ms/step - loss: 0.0249 - val_loss: 0.0330
# Epoch 4/25
# 65/65 - 0s - 5ms/step - loss: 0.0212 - val_loss: 0.0360
# Epoch 5/25
# 65/65 - 0s - 5ms/step - loss: 0.0199 - val_loss: 0.0339
# Epoch 6/25
# 65/65 - 0s - 6ms/step - loss: 0.0190 - val_loss: 0.0317
# Epoch 7/25
# 65/65 - 0s - 6ms/step - loss: 0.0189 - val_loss: 0.0290
# Epoch 8/25
# 65/65 - 0s - 5ms/step - loss: 0.0175 - val_loss: 0.0310
# Epoch 9/25
# 65/65 - 0s - 5ms/step - loss: 0.0180 - val_loss: 0.0306
# Epoch 10/25
# 65/65 - 0s - 5ms/step - loss: 0.0165 - val_loss: 0.0303
# Epoch 11/25
# 65/65 - 0s - 5ms/step - loss: 0.0164 - val_loss: 0.0304
# Epoch 12/25
# 65/65 - 0s - 5ms/step - loss: 0.0157 - val_loss: 0.0313
# Epoch 13/25
# 65/65 - 0s - 6ms/step - loss: 0.0153 - val_loss: 0.0310
# Epoch 14/25
# 65/65 - 0s - 5ms/step - loss: 0.0159 - val_loss: 0.0295
# Epoch 15/25
# 65/65 - 0s - 6ms/step - loss: 0.0154 - val_loss: 0.0284
# Epoch 16/25
# 65/65 - 0s - 4ms/step - loss: 0.0155 - val_loss: 0.0301
# Epoch 17/25
# 65/65 - 0s - 5ms/step - loss: 0.0148 - val_loss: 0.0300
# Epoch 18/25
# 65/65 - 0s - 5ms/step - loss: 0.0145 - val_loss: 0.0302
# Epoch 19/25
# 65/65 - 0s - 6ms/step - loss: 0.0142 - val_loss: 0.0320
# Epoch 20/25
# 65/65 - 0s - 5ms/step - loss: 0.0150 - val_loss: 0.0302
# Epoch 21/25
# 65/65 - 0s - 5ms/step - loss: 0.0147 - val_loss: 0.0300
# Epoch 22/25
# 65/65 - 0s - 5ms/step - loss: 0.0140 - val_loss: 0.0304
# Epoch 23/25
# 65/65 - 0s - 6ms/step - loss: 0.0161 - val_loss: 0.0294
# Epoch 24/25
# 65/65 - 0s - 5ms/step - loss: 0.0141 - val_loss: 0.0286
# Epoch 25/25
# 65/65 - 0s - 4ms/step - loss: 0.0156 - val_loss: 0.0301
# El entrenamiento se ha completado y el historial ha sido guardado en '{history_filename}'
# Cargando el mejor modelo: sequential_38_15-0.0284.keras con val_loss: 0.0284
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(test[5:].index, y_testr, label='Cargas diarias transportadas', color='blue')
plt.plot(test[5:].index, test_pred, label='Pronóstico Forecast', color='orange', linestyle='--')
plt.title('Comparación de Pronóstico y test con RNN')
plt.xlabel('Fecha')
plt.ylabel('Cargas transportadas')
plt.legend()
plt.show()

# %% [markdown]
# Se observa un mucho mejor ajuste que el anteriormente obtenido usando modelos de tipo ARIMA y suavización exponencial.
